# %%
import requests

# %% [markdown]
# ```bash
# curl -X POST "https://accounts.spotify.com/api/token" \
#      -H "Content-Type: application/x-www-form-urlencoded" \
#      -d "grant_type=client_credentials&client_id=your-client-id&client_secret=your-client-secret"
#
# ```

# %%
# Getting a valid request token:
data = {
    "grant_type": "client_credentials",
    "response_type": "code",
    "client_id": "9820a6f3240f45a2a99a5246ed4a1fd5",
    "client_secret": "d0f99343e07d4c479715383d551d992d",
    "scope": "user-read-recently-played"
}

response = requests.post("https://accounts.spotify.com/api/token", data=data)

request_token = response.json()
request_token
# Out:
# {'access_token': 'BQCfIiHLE-ZAPSzXwnxjJaPP6sDdLpUzDYhqKL8VBJucA8vMt6rx95TdfjrMkETGfbw4FUhL0D_T4xT_NGkyCi5yBJZUItV85qJLwVq4y8PDWv8-JRGFE-dtO-svDk44wFgHPlEwZJZyeMLr',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': 'user-read-recently-played'}

# %%
from datetime import datetime
base_url = "https://api.spotify.com/v1"
recently_played_url = "/me/player/recently-played"
recently_played_data = {"limit":str(10),
                        "after":str(int(datetime.strptime(datetime.today().strftime("%Y-%m-%d"), "%Y-%m-%d").timestamp() * 1000 - 3600*24*1000)),
                        }
headers = {
    "Authorization": request_token['token_type'] + " " + request_token['access_token']
}

response_2 = requests.get(base_url+recently_played_url, headers=headers, params=recently_played_data)

# %%
import requests

headers = {
    'Authorization': "Bearer BQB746xRuJklZ9tPFXQYZPJgCm_yGLLadtny54G8Ug8kF9XcEc0iWp8Y-kMGAIICtVnHf1eQ-s36UnZ7WNAyzMTR_M3lBrb1psGaALphgriTe2d2zBeaw37p2IE51VGpvFh4f_ABnYM",
}

params = {
    'limit': 10,
    'after': 1764025200000,
}

response = requests.get('https://api.spotify.com/v1/me/player/recently-played', params=params, headers=headers)

# %%
response.content
# Out:
# b'{\n  "error" : {\n    "status" : 403,\n    "message" : "Insufficient client scope"\n  }\n}'

# %%
response_2.url
# Out:
# 'https://api.spotify.com/v1/me/player/recently-played?limit=10&after=1764025200000'

# %%
from datetime import datetime, timezone
ms = int("1484811043508")
print(datetime.fromtimestamp(ms/1000.0, tz=timezone.utc))
# Out:
# 2017-01-19 07:30:43.508000+00:00

# %%
# convert from timestamp to ms
q = datetime.strptime(datetime.today().strftime("%Y-%m-%d"), "%Y-%m-%d").timestamp() * 1000 - 3600 * 24 * 1000
q
# Out:
# 1764025200000.0

# %%
print(datetime.fromtimestamp(q/1000.0))
print(datetime.strptime(datetime.today().strftime("%Y-%m-%d"), "%Y-%m-%d"))
# Out:
# 2025-11-25 00:00:00
# 2025-11-26 00:00:00

# %% [markdown]
# ## Request User Authorization

# %%
import requests
client_id = "9820a6f3240f45a2a99a5246ed4a1fd5"
response_type = "code"
redirect_uri = "http://127.0.0.1:8000/callback"
# state = # recommended
scope = "user-read-recently-played"

data = {
    "response_type": response_type,
    "client_id": client_id,
    "scope": scope,
    "redirect_uri": redirect_uri
}

response = requests.get("https://accounts.spotify.com/authorize", headers=data)

# %%
response
# Out:
# <Response [200]>
