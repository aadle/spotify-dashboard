# %%
import requests
import json

# %%
with open("secrets/lastfm.json") as f:
    client_json = json.load(f)

# %%
base_url = "http://ws.audioscrobbler.com/2.0/"

# test to see if we get response
headers = {
    "user-agent": "python-tester"
}

payload = {
    "api_key": client_json["client_id"],
    "method": "chart.gettopartists",
    "format": "json"
}

r = requests.get(base_url, headers=headers, params=payload)
r.status_code
# Out:
# 200

# %%
# test to get auth token
auth_payload = {
    "api_key": client_json["client_id"],
    "method": "auth.gettoken",
    "format": "json"
}

auth_r = requests.get(base_url, headers=headers, params=auth_payload)
auth_r.status_code
# Out:
# 200

# %%
auth_token = auth_r.json()["token"]
print(auth_token)
# Out:
# RPkvErMFrnZs5GDjNyy6sJwWk-hZ5lvS

# %%
# authenticate user?
import webbrowser

auth_request_url = "http://www.last.fm/api/auth"
request_auth_payload = {
    "api_key": client_json["client_id"],
    "token": auth_token
}

request_auth_r = requests.get(auth_request_url, headers=headers, params=request_auth_payload)
request_auth_r.status_code

webbrowser.open(request_auth_r.url)
# Out:
# True

# %%
# signing calls, needed for use of services
import hashlib
auth_payload = {
    "api_key": client_json["client_id"],
    "method": "auth.gettoken",
    "format": "json"
}
request_params_signing = "".join([str(k)+str(v) for k, v in auth_payload.items()][:-1]) + client_json["client_secret"]
print(request_params_signing)
print(hashlib.md5(request_params_signing.encode()))

# signing needs
    # - api key
    # - api secret
    # - method
# join "api_key"+api_key-value, "method"+method-string and api_secret
# Out:
# api_key96e8b6dd8a4702e9e058ed121094987fmethodauth.gettoken7f65cc958a0fe5800a535207c43fbcc9
# <md5 _hashlib.HASH object @ 0x105da9bb0>

# %%
[str(k)+str(v) for k, v in auth_payload.items()][:-1]
# Out:
# ['api_key96e8b6dd8a4702e9e058ed121094987f', 'methodauth.gettoken']

# %% [markdown]
# lol getRecentTracks trenger ikke auth.

# %%
import pytz
from datetime import datetime, timedelta
import webbrowser
import requests
today = pytz.utc.localize(datetime.now().replace(hour=0, minute=0, second=0, microsecond=0))
yesterday = today - timedelta(days=5)
today_ms = int(today.timestamp())
yesterday_ms = int(yesterday.timestamp())

base_url = "http://ws.audioscrobbler.com/2.0/"

headers = {
    "user-agent": "GP-personal-app"
}

recent_tracks_params = {
    "limit": 20,
    "user": "GammelPerson",
    "from": yesterday_ms,
    "to": today_ms,
    "extended": 0,
    "api_key": client_json["client_id"],
    "format": "json",
    "method": "user.getrecenttracks",
}

r = requests.get(base_url, headers=headers, params=recent_tracks_params)
webbrowser.open(r.url)
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'http://ws.audioscrobbler.com/2.0/?limit=20&user=GammelPerson&from=1764115200&to=1764547200&extended=1&api_key=96e8b6dd8a4702e9e058ed121094987f&format=json&method=user.getrecenttracks'

# %%
date_format = "%Y-%m-%d"
end = "2025-12-01"
int(
        pytz.utc.localize(datetime.strptime(end, date_format)).timestamp()
    )
# Out:
# 1764547200

# %%
webbrowser.open(r.url)
# Out:
# True

# %% [markdown]
# Response er en .json-fil. Den har to nøkler på høyeste nivå, `recent_tracks` og `@attr`. Gitt at du gjør et søk over en lenger periode, for eksempel her med flere dagers mellomrom, er det mulig å få antall sider med resultater i `@attr`. I `recent_tracks.tracks` finner man da all sanginfoen.
#
# Det går vel an å bruke dette for å hente hele lyttehistorien min fra 01.01-30.11. Bare at jeg kanskje burde indeksere sidene og dumpe resultatene til json. Vet ikke om dette overskrider rate_limit satt av last.fm.

# %%
r.url
# Out:
# 'http://ws.audioscrobbler.com/2.0/?limit=20&user=GammelPerson&from=1764288000000&to=1764374400000&extended=1&api_key=96e8b6dd8a4702e9e058ed121094987f&format=json&method=user.getrecenttracks'

# %%
q = r.json()

# %%
q
# Out:
# {'recenttracks': {'track': [{'artist': {'mbid': '', '#text': 'Slimesito'},
#     'streamable': '0',
#     'image': [{'size': 'small',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/a9198665ef7ca70d920e25c509d322ba.jpg'},
#      {'size': 'medium',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/a9198665ef7ca70d920e25c509d322ba.jpg'},
#      {'size': 'large',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/a9198665ef7ca70d920e25c509d322ba.jpg'},
#      {'size': 'extralarge',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/a9198665ef7ca70d920e25c509d322ba.jpg'}],
#     'mbid': '',
#     'album': {'mbid': '', '#text': 'Pray 4 Me'},
#     'name': 'Pray 4 Me',
#     'url': 'https://www.last.fm/music/Slimesito/_/Pray+4+Me',
#     'date': {'uts': '1764531747', '#text': '30 Nov 2025, 19:42'}},
#    {'artist': {'mbid': 'ec29539f-4e72-46af-9fb0-b5697a3cf41b',
#      '#text': 'Evita Manji'},
#     'streamable': '0',
#     'image': [{'size': 'small',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/49d913353ae9b30e4df493b16613274a.jpg'},
#      {'size': 'medium',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/49d913353ae9b30e4df493b16613274a.jpg'},
#      {'size': 'large',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/49d913353ae9b30e4df493b16613274a.jpg'},
#      {'size': 'extralarge',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/49d913353ae9b30e4df493b16613274a.jpg'}],
#     'mbid': '13df944e-ab2b-4e9b-955e-92bdff58b00d',
#     'album': {'mbid': '', '#text': 'Body/Prison'},
#     'name': 'Body/Prison',
#     'url': 'https://www.last.fm/music/Evita+Manji/_/Body%2FPrison',
#     'date': {'uts': '1764526996', '#text': '30 Nov 2025, 18:23'}},
#    {'artist': {'mbid': 'ec29539f-4e72-46af-9fb0-b5697a3cf41b',
#      '#text': 'Evita Manji'},
#     'streamable': '0',
#     'image': [{'size': 'small',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#      {'size': 'medium',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#      {'size': 'large',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#      {'size': 'extralarge',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/bebc682ba18af20d091c9bb2edcdab0f.jpg'}],
#     'mbid': '',
#     'album': {'mbid': '60f529ea-a4ac-4292-9433-2cab9b7042f2',
#      '#text': 'Spandrel?'},
#     'name': 'OIL/TOO MUCH',
#     'url': 'https://www.last.fm/music/Evita+Manji/_/OIL%2FTOO+MUCH',
#     'date': {'uts': '1764526756', '#text': '30 Nov 2025, 18:19'}},
#    {'artist': {'mbid': 'e0c97a4d-c392-41a9-a374-57af3e3eeab3',
#      '#text': 'Geese'},
#     'streamable': '0',
#     'image': [{'size': 'small',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/75695cd196406316f055a757728c6ee7.jpg'},
#      {'size': 'medium',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/75695cd196406316f055a757728c6ee7.jpg'},
#      {'size': 'large',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/75695cd196406316f055a757728c6ee7.jpg'},
#      {'size': 'extralarge',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/75695cd196406316f055a757728c6ee7.jpg'}],
#     'mbid': '3b8f97ce-12ad-4ae9-a39f-0e7ffd91da5d',
#     'album': {'mbid': '0bf006ce-45a5-4963-89cb-cd285fd768bb',
#      '#text': 'Getting Killed'},
#     'name': 'Husbands',
#     'url': 'https://www.last.fm/music/Geese/_/Husbands',
#     'date': {'uts': '1764526507', '#text': '30 Nov 2025, 18:15'}},
#    {'artist': {'mbid': 'e0c97a4d-c392-41a9-a374-57af3e3eeab3',
#      '#text': 'Geese'},
#     'streamable': '0',
#     'image': [{'size': 'small',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/75695cd196406316f055a757728c6ee7.jpg'},
#      {'size': 'medium',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/75695cd196406316f055a757728c6ee7.jpg'},
#      {'size': 'large',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/75695cd196406316f055a757728c6ee7.jpg'},
#      {'size': 'extralarge',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/75695cd196406316f055a757728c6ee7.jpg'}],
#     'mbid': 'dd0dd10c-4890-4056-b93c-1cf0c974fb85',
#     'album': {'mbid': '0bf006ce-45a5-4963-89cb-cd285fd768bb',
#      '#text': 'Getting Killed'},
#     'name': 'Cobra',
#     'url': 'https://www.last.fm/music/Geese/_/Cobra',
#     'date': {'uts': '1764526307', '#text': '30 Nov 2025, 18:11'}},
#    {'artist': {'mbid': '284a5c91-3d9c-4fca-b5a5-1c5d8ab6d528',
#      '#text': 'Slimesito'},
#     'streamable': '0',
#     'image': [{'size': 'small',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/34s
jpg'},
#      {'size': 'large',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/ea1a1549811716351ebca13e976ae852.jpg'},
#      {'size': 'extralarge',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/ea1a1549811716351ebca13e976ae852.jpg'}],
#     'mbid': '05bcf15b-cfc6-4037-85b9-cd250dac55f2',
#     'album': {'mbid': '', '#text': 'Ef'},
#     'name': 'Ef',
#     'url': 'https://www.last.fm/music/Chanel+Beads/_/Ef',
#     'date': {'uts': '1764523867', '#text': '30 Nov 2025, 17:31'}},
#    {'artist': {'mbid': 'ec29539f-4e72-46af-9fb0-b5697a3cf41b',
#      '#text': 'Evita Manji'},
#     'streamable': '0',
#     'image': [{'size': 'small',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#      {'size': 'medium',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#      {'size': 'large',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#      {'size': 'extralarge',
#       '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/bebc682ba18af20d091c9bb2edcdab0f.jpg'}],
#     'mbid': '',
#     'album': {'mbid': '60f529ea-a4ac-4292-9433-2cab9b7042f2',
#      '#text': 'Spandrel?'},
#     'name': 'OIL/TOO MUCH',
#     'url': 'https://www.last.fm/music/Evita+Manji/_/OIL%2FTOO+MUCH',
#     'date': {'uts': '1764516524', '#text': '30 Nov 2025, 15:28'}}],
#   '@attr': {'user': 'GammelPerson',
#    'totalPages': '14',
#    'page': '1',
#    'total': '274',
#    'perPage': '20'}}}

# %%
q["recenttracks"]["track"]
# Out:
# [{'artist': {'mbid': '', '#text': 'Slimesito'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/a9198665ef7ca70d920e25c509d322ba.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/a9198665ef7ca70d920e25c509d322ba.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/a9198665ef7ca70d920e25c509d322ba.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/a9198665ef7ca70d920e25c509d322ba.jpg'}],
#   'mbid': '',
#   'album': {'mbid': '', '#text': 'Pray 4 Me'},
#   'name': 'Pray 4 Me',
#   'url': 'https://www.last.fm/music/Slimesito/_/Pray+4+Me',
#   'date': {'uts': '1764531747', '#text': '30 Nov 2025, 19:42'}},
#  {'artist': {'mbid': 'ec29539f-4e72-46af-9fb0-b5697a3cf41b',
#    '#text': 'Evita Manji'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/49d913353ae9b30e4df493b16613274a.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/49d913353ae9b30e4df493b16613274a.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/49d913353ae9b30e4df493b16613274a.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/49d913353ae9b30e4df493b16613274a.jpg'}],
#   'mbid': '13df944e-ab2b-4e9b-955e-92bdff58b00d',
#   'album': {'mbid': '', '#text': 'Body/Prison'},
#   'name': 'Body/Prison',
#   'url': 'https://www.last.fm/music/Evita+Manji/_/Body%2FPrison',
#   'date': {'uts': '1764526996', '#text': '30 Nov 2025, 18:23'}},
#  {'artist': {'mbid': 'ec29539f-4e72-46af-9fb0-b5697a3cf41b',
#    '#text': 'Evita Manji'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/bebc682ba18af20d091c9bb2edcdab0f.jpg'}],
#   'mbid': '',
#   'album': {'mbid': '60f529ea-a4ac-4292-9433-2cab9b7042f2',
#    '#text': 'Spandrel?'},
#   'name': 'OIL/TOO MUCH',
#   'url': 'https://www.last.fm/music/Evita+Manji/_/OIL%2FTOO+MUCH',
#   'date': {'uts': '1764526756', '#text': '30 Nov 2025, 18:19'}},
#  {'artist': {'mbid': 'e0c97a4d-c392-41a9-a374-57af3e3eeab3', '#text': 'Geese'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/75695cd196406316f055a757728c6ee7.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/75695cd196406316f055a757728c6ee7.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/75695cd196406316f055a757728c6ee7.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/75695cd196406316f055a757728c6ee7.jpg'}],
#   'mbid': '3b8f97ce-12ad-4ae9-a39f-0e7ffd91da5d',
#   'album': {'mbid': '0bf006ce-45a5-4963-89cb-cd285fd768bb',
#    '#text': 'Getting Killed'},
#   'name': 'Husbands',
#   'url': 'https://www.last.fm/music/Geese/_/Husbands',
#   'date': {'uts': '1764526507', '#text': '30 Nov 2025, 18:15'}},
#  {'artist': {'mbid': 'e0c97a4d-c392-41a9-a374-57af3e3eeab3', '#text': 'Geese'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/75695cd196406316f055a757728c6ee7.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/75695cd196406316f055a757728c6ee7.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/75695cd196406316f055a757728c6ee7.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/75695cd196406316f055a757728c6ee7.jpg'}],
#   'mbid': 'dd0dd10c-4890-4056-b93c-1cf0c974fb85',
#   'album': {'mbid': '0bf006ce-45a5-4963-89cb-cd285fd768bb',
#    '#text': 'Getting Killed'},
#   'name': 'Cobra',
#   'url': 'https://www.last.fm/music/Geese/_/Cobra',
#   'date': {'uts': '1764526307', '#text': '30 Nov 2025, 18:11'}},
#  {'artist': {'mbid': '284a5c91-3d9c-4fca-b5a5-1c5d8ab6d528',
#    '#text': 'Slimesito'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/e1272923dbfb4b26130e0527884c0e10.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/e1272923dbfb4b26130e0527884c0e10.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/e1272923dbfb4b26130e0527884c0e10.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/e1272923dbfb4b26130e0527884c0e10.jpg'}],
#   'mbid': '8a6c38bf-e5df-42c3-bf08-a1637a9a4645',
#   'album': {'mbid': '4d240374-ea8d-419a-a1d8-3df0a949152d', '#text': 'GTA9'},
#   'name': 'Ms. Jackson',
#   'url': 'https://www.last.fm/music/Slimesito/_/Ms.+Jackson',
#   'date': {'uts': '1764526179', '#text': '30 Nov 2025, 18:09'}},
#  {'artist': {'mbid': '', '#text': 'Oli XL'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/5061e393683af00900d510a914bb98cb.png'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/5061e393683af00900d510a914bb98cb.png'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/5061e393683af00900d510a914bb98cb.png'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/5061e393683af00900d510a914bb98cb.png'}],
#   'mbid': '',
#   'album': {'mbid': '', '#text': 'Lick The Lens – Pt.1'},
#   'name': 'CONSPIRACY GIRL',
#   'url': 'https://www.last.fm/music/Oli+XL/_/CONSPIRACY+GIRL',
#   'date': {'uts': '1764526017', '#text': '30 Nov 2025, 18:06'}},
#  {'artist': {'mbid': '', '#text': 'EsDeeKid'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/08e715c0f5f7e77f6f1c6014e0f3e7d4.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/08e715c0f5f7e77f6f1c6014e0f3e7d4.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/08e715c0f5f7e77f6f1c6014e0f3e7d4.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/08e715c0f5f7e77f6f1c6014e0f3e7d4.jpg'}],
#   'mbid': '',
#   'album': {'mbid': '', '#text': 'Rebel'},
#   'name': '4 Raws',
#   'url': 'https://www.last.fm/music/EsDeeKid/_/4+Raws',
#   'date': {'uts': '1764525898', '#text': '30 Nov 2025, 18:04'}},
#  {'artist': {'mbid': '1550f952-c91b-40d7-9b4d-d26a259ee932', '#text': 'Lil B'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/6359420f4d3f413db3dbfd96e53cfa18.png'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/6359420f4d3f413db3dbfd96e53cfa18.png'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/6359420f4d3f413db3dbfd96e53cfa18.png'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/6359420f4d3f413db3dbfd96e53cfa18.png'}],
#   'mbid': 'd9d58ecf-3726-40eb-80c8-eccbba80e333',
#   'album': {'mbid': '66a82f75-a814-4c79-9457-a4ac7d0d2186',
#    '#text': 'Everything Based'},
#   'name': 'Suck My Dick Hoe',
#   'url': 'https://www.last.fm/music/Lil+B/_/Suck+My+Dick+Hoe',
#   'date': {'uts': '1764525635', '#text': '30 Nov 2025, 18:00'}},
#  {'artist': {'mbid': '', '#text': 'Ethereal'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/9f73fd5a7f98e53ab8215504a99646ed.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/9f73fd5a7f98e53ab8215504a99646ed.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/9f73fd5a7f98e53ab8215504a99646ed.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/9f73fd5a7f98e53ab8215504a99646ed.jpg'}],
#   'mbid': '',
#   'album': {'mbid': '', '#text': 
},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/200becffa57d98843e30a6ff14601546.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/200becffa57d98843e30a6ff14601546.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/200becffa57d98843e30a6ff14601546.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/200becffa57d98843e30a6ff14601546.jpg'}],
#   'mbid': 'b1ed2cc3-c2d5-4fad-88a1-8ebfc72a06b2',
#   'album': {'mbid': '', '#text': "Should've known better (choices)"},
#   'name': "Should've known better (choices)",
#   'url': 'https://www.last.fm/music/Becky+and+the+Birds/_/Should%27ve+known+better+(choices)',
#   'date': {'uts': '1764524046', '#text': '30 Nov 2025, 17:34'}},
#  {'artist': {'mbid': '00a8bd6b-4cb2-491c-8fe5-3fca06909973',
#    '#text': 'Chanel Beads'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/ea1a1549811716351ebca13e976ae852.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/ea1a1549811716351ebca13e976ae852.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/ea1a1549811716351ebca13e976ae852.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/ea1a1549811716351ebca13e976ae852.jpg'}],
#   'mbid': '05bcf15b-cfc6-4037-85b9-cd250dac55f2',
#   'album': {'mbid': '', '#text': 'Ef'},
#   'name': 'Ef',
#   'url': 'https://www.last.fm/music/Chanel+Beads/_/Ef',
#   'date': {'uts': '1764523867', '#text': '30 Nov 2025, 17:31'}},
#  {'artist': {'mbid': 'ec29539f-4e72-46af-9fb0-b5697a3cf41b',
#    '#text': 'Evita Manji'},
#   'streamable': '0',
#   'image': [{'size': 'small',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#    {'size': 'medium',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#    {'size': 'large',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/bebc682ba18af20d091c9bb2edcdab0f.jpg'},
#    {'size': 'extralarge',
#     '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/bebc682ba18af20d091c9bb2edcdab0f.jpg'}],
#   'mbid': '',
#   'album': {'mbid': '60f529ea-a4ac-4292-9433-2cab9b7042f2',
#    '#text': 'Spandrel?'},
#   'name': 'OIL/TOO MUCH',
#   'url': 'https://www.last.fm/music/Evita+Manji/_/OIL%2FTOO+MUCH',
#   'date': {'uts': '1764516524', '#text': '30 Nov 2025, 15:28'}}]

# %%
pytz.utc.localize(datetime(year=2025, month=1, day=1, hour=0, minute=0, second=0))
# Out:
# datetime.datetime(2025, 1, 1, 0, 0, tzinfo=<UTC>)

# %%
# Sjekke hvor mange .json filer jeg må dumpe hvis vi henter 50 sanger per request.

import pytz
from datetime import datetime, timedelta
end = pytz.utc.localize(datetime(year=2025, month=12, day=1, hour=0, minute=0, second=0))
start = pytz.utc.localize(datetime(year=2025, month=1, day=1, hour=0, minute=0, second=0))
start_ms = int(start.timestamp())
end_ms = int(end.timestamp())

base_url = "http://ws.audioscrobbler.com/2.0/"

recent_tracks_params = {
    "limit": 50,
    "user": "GammelPerson",
    "from": start_ms,
    "to": end_ms,
    "extended": 0,
    "api_key": client_json["client_id"],
    "format": "json",
    "method": "user.getrecenttracks",
    "page": 1,
}

r = requests.get(base_url, headers=headers, params=recent_tracks_params)
webbrowser.open(r.url)
r.status_code

print(r.json()["recenttracks"]["@attr"])
# Out:
# {'user': 'GammelPerson', 'totalPages': '321', 'page': '1', 'perPage': '50', 'total': '16022'}

# %% [markdown]
# I perioden 01.01-30.11 blir det totalt 321 sider, eller 321 .json-filer totalt.
#
# Kan lage en cron-jobb som tar og samler inn data fra foregående dag.
