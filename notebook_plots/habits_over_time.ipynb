# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
from local_utils.retrieval import get_table_data
import pandas as pd

# %%
listening_history =  get_table_data("temp_listening_history", "SELECT artist_name, track_name, listened_at FROM temp_listening_history;")

# %%
listening_history
# Out:
# [{'artist_name': 'Mac DeMarco',
#   'track_name': 'This Old Dog',
#   'listened_at': datetime.datetime(2021, 10, 23, 16, 56, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Verzache',
#   'track_name': 'attached',
#   'listened_at': datetime.datetime(2021, 10, 23, 16, 51, 18, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lokoy',
#   'track_name': 'relay',
#   'listened_at': datetime.datetime(2021, 10, 23, 16, 48, 40, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'svjcartier',
#   'track_name': 'Medusa',
#   'listened_at': datetime.datetime(2021, 10, 23, 15, 0, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Gus Dapperton',
#   'track_name': 'Prune, You Talk Funny',
#   'listened_at': datetime.datetime(2021, 10, 23, 14, 49, 20, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'My Kind of Woman',
#   'listened_at': datetime.datetime(2021, 10, 23, 14, 45, 27, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'The Stars Keep on Calling My Name',
#   'listened_at': datetime.datetime(2021, 10, 23, 14, 43, 37, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'Ode to Viceroy',
#   'listened_at': datetime.datetime(2021, 10, 23, 14, 41, 2, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kevin Abstract',
#   'track_name': 'Sierra Nights (feat. Ryan Beatty)',
#   'listened_at': datetime.datetime(2021, 10, 23, 14, 17, 55, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Billie Eilish',
#   'track_name': 'bitches broken hearts',
#   'listened_at': datetime.datetime(2021, 10, 23, 14, 14, 58, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bobby Caldwell',
#   'track_name': "What You Won't Do for Love",
#   'listened_at': datetime.datetime(2021, 10, 23, 14, 8, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '100 gecs',
#   'track_name': 'hand crushed by a mallet',
#   'listened_at': datetime.datetime(2021, 10, 23, 14, 5, 2, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '100 gecs',
#   'track_name': '800 db cloud',
#   'listened_at': datetime.datetime(2021, 10, 23, 14, 2, 42, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '100 gecs',
#   'track_name': 'money machine',
#   'listened_at': datetime.datetime(2021, 10, 23, 14, 0, 48, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '100 gecs',
#   'track_name': 'toothless',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 56, 57, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '100 gecs',
#   'track_name': 'ringtone',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 54, 35, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Jonatan Leandoer96',
#   'track_name': 'Wooden Girl',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 50, 37, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'KAYTRANADA',
#   'track_name': '10%',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 46, 35, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Night Lovell',
#   'track_name': 'Lethal Presence',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 46, 35, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Night Lovell',
#   'track_name': 'Lethal Presence',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 44, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'SOUDIERE',
#   'track_name': 'DEMONS IN MY SOUL',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 37, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Aphex Twin',
#   'track_name': 's950tx16wasr10 [163.97][earth portal mix]',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 31, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Zack Fox',
#   'track_name': 'FAFO',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 28, 29, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'vierre cloud',
#   'track_name': 'moment',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 26, 20, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Cmon',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 24, 37, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Playboi Carti',
#   'track_name': 'Stop Breathing',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 19, 33, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Teen Suicide',
#   'track_name': 'Alex',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 15, 13, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Teen Suicide',
#   'track_name': "It's Just A Pop Song",
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 11, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Zack Fox',
#   'track_name': 'FAFO',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 5, 32, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'For the First Time',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 4, 6, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'One Another',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 4, 5, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'For the First Time',
#   'listened_at': datetime.datetime(2021, 10, 23, 13, 1, 3, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': "Baby You're Out",
#   'listened_at': datetime.datetime(2021, 10, 23, 12, 58, 26, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'This Old Dog',
#   'listened_at': datetime.datetime(2021, 10, 23, 12, 55, 53, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'My Old Man',
#   'listened_at': datetime.datetime(2021, 10, 23, 12, 52, 2, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bobby Caldwell',
#   'track_name': "What You Won't Do for Love",
#   'listened_at': datetime.datetime(2021, 10, 23, 12, 47, 7, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'TisaKorean',
#   'track_name': 'Silly Achilles',
#   'listened_at': datetime.datetime(2021, 10, 23, 12, 45, 26, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'Moonlight on the River',
#   'listened_at': datetime.datetime(2021, 10, 23, 12, 41, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Billie Eilish',
#   'track_name': 'bitches broken hearts',
#   'listened_at': datetime.datetime(2021, 10, 23, 12, 35, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Billie Eilish',
#   'track_name': 'ocean eyes',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 59, 17, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Billie Eilish',
#   'track_name': 'party favor',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 55, 47, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Billie Eilish',
#   'track_name': 'idontwannabeyouanymore',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 52, 25, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Billie Eilish',
#   'track_name': 'hostage',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 48, 59, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Joji',
#   'track_name': 'Bitter Fuck (salute remix)',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 45, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mr. Carmack',
#   'track_name': 'The Next Afternoon',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 41, 55, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dominic Fike',
#   'track_name': 'Socks',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 39, 34, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Unknown Mortal Orchestra',
#   'track_name': 'If You’re Going to Break Yourself',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 34, 39, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'dvr',
#   'track_name': 'thru the city',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 34, 39, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'dvr',
#   'track_name': 'thru the city',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 32, 8, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kankan Archived',
#   'track_name': 'X n Oxy',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 29, 13, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Chicago',
#   'track_name': 'If You Leave Me Now',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 24, 26, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bobby Caldwell',
#   'track_name': "What You Won't Do for Love",
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 19, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Makoto Matsushita',
#   'track_name': 'Love Was Really Gone - 2018 Remaster',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 13, 43, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Makoto Matsushita',
#   'track_name': 'September Rain - 2020 Remaster',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 9, 8, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Player',
#   'track_name': 'Baby Come Back',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 5, 33, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Grover Washington, Jr.',
#   'track_name': 'Just the Two of Us (feat. Bill Withers)',
#   'listened_at': datetime.datetime(2021, 10, 23, 11, 1, 36, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'The Ponderosa Twins Plus One',
#   'track_name': 'Bound',
#   'listened_at': datetime.datetime(2021, 10, 23, 10, 58, 20, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'svjcartier',
#   'track_name': 'Medusa',
#   'listened_at': datetime.datetime(2021, 10, 23, 10, 56, 29, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Cochise',
#   'track_name': 'Pocket Rocket',
#   'listened_at': datetime.datetime(2021, 10, 23, 10, 54, 53, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Beach House',
#   'track_name': 'Space Song',
#   'listened_at': datetime.datetime(2021, 10, 23, 10, 35, 7, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Zack Fox',
#   'track_name': 'FAFO',
#   'listened_at': datetime.datetime(2021, 10, 23, 9, 47, 7, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'vierre cloud',
#   'track_name': 'moment',
#   'listened_at': datetime.datetime(2021, 10, 23, 9, 44, 57, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Cmon',
#   'listened_at': datetime.datetime(2021, 10, 23, 9, 43, 15, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Tyler, The Creator',
#   'track_name': 'RUNNING OUT OF TIME',
#   'listened_at': datetime.datetime(2021, 10, 23, 9, 39, 39, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bobby Caldwell',
#   'track_name': "What You Won't Do for Love",
#   'listened_at': datetime.datetime(2021, 10, 23, 8, 42, 24, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bobby Caldwell',
#   'track_name': "What You Won't Do for Love",
#   'listened_at': datetime.datetime(2021, 10, 23, 8, 42, 20, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'p4rkr',
#   'track_name': 'two am',
#   'listened_at': datetime.datetime(2021, 10, 22, 19, 5, 19, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'EYUKALIPTUS',
#   'track_name': 'IDONTLOVEYOU',
#   'listened_at': datetime.datetime(2021, 10, 22, 19, 3, 38, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yung Lean',
#   'track_name': 'Violence',
#   'listened_at': datetime.datetime(2021, 10, 22, 19, 0, 46, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'Moonlight on the River',
#   'listened_at': datetime.datetime(2021, 10, 22, 18, 53, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Pharrell Williams',
#   'track_name': 'Happy - From "Despicable Me 2"',
#   'listened_at': datetime.datetime(2021, 10, 22, 18, 42, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kaja Gunnufsen',
#   'track_name': 'Sukkerspinn',
#   'listened_at': datetime.datetime(2021, 10, 22, 18, 38, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Teen Suicide',
#   'track_name': 'grim reaper',
#   'listened_at': datetime.datetime(2021, 10, 22, 18, 37, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '88rising',
#   'track_name': 'Beam (feat. Playboi Carti)',
#   'listened_at': datetime.datetime(2021, 10, 22, 18, 34, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'dvr',
#   'track_name': 'thru the city',
#   'listened_at': datetime.datetime(2021, 10, 22, 18, 31, 40, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'QUICKLY, QUICKLY',
#   'track_name': 'luvagain',
#   'listened_at': datetime.datetime(2021, 10, 22, 17, 42, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'nascar aloe',
#   'track_name': 'FEET!',
#   'listened_at': datetime.datetime(2021, 10, 22, 17, 40, 24, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'TisaKorean',
#   'track_name': 'Silly Achilles',
#   'listened_at': datetime.datetime(2021, 10, 22, 17, 38, 52, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Julia Brown',
#   'track_name': 'Possession (full)',
#   'listened_at': datetime.datetime(2021, 10, 22, 15, 30, 39, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Teen Suicide',
#   'track_name': 'afterlife dating',
#   'listened_at': datetime.datetime(2021, 10, 22, 15, 28, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mickey Darling',
#   'track_name': 'Feed My Ego',
#   'listened_at': datetime.datetime(2021, 10, 22, 13, 15, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Drippin So Pretty',
#   'track_name': 'Bad News',
#   'listened_at': datetime.datetime(2021, 10, 22, 13, 13, 3, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Pham',
#   'track_name': 'Alibi',
#   'listened_at': datetime.datetime(2021, 10, 22, 13, 9, 10, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kaja Gunnufsen',
#   'track_name': 'Sukkerspinn',
#   'listened_at': datetime.datetime(2021, 10, 22, 13, 5, 10, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Maggie Rogers',
#   'track_name': 'Say It',
#   'listened_at': datetime.datetime(2021, 10, 22, 13, 1, 30, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Semiset',
#   'track_name': 'Fruit',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 45, 32, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Semiset',
#   'track_name': 'Disco',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 45, 32, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Semiset',
#   'track_name': 'Fruit',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 43, 14, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Semiset',
#   'track_name': 'Space',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 39, 39, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Playboi Carti',
#   'track_name': 'Lean 4 Real (feat. Skepta)',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 37, 13, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Tyler, The Creator',
#   'track_name': 'A BOY IS A GUN*',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 29, 13, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Otto',
#   'track_name': 'About You Now',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 25, 10, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Rina Sawayama',
#   'track_name': 'Comme des Garçons (Like the Boys)',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 21, 54, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Thaiboy Digital',
#   'track_name': '30th Floor',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 20, 29, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Joji',
#   'track_name': 'YEAH RIGHT',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 15, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'WEEDMANE',
#   'track_name': 'SUICIDE YEAR',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 13, 28, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kankan Archived',
#   'track_name': 'X n Oxy',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 10, 30, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Cocteau Twins',
#   'track_name': 'Cherry-Coloured Funk',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 7, 18, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Pixies',
#   'track_name': 'Where Is My Mind? - Remastered',
#   'listened_at': datetime.datetime(2021, 10, 22, 12, 3, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bobby Caldwell',
#   'track_name': "What You Won't Do for Love",
#   'listened_at': datetime.datetime(2021, 10, 22, 11, 58, 35, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ulla',
#   'track_name': 'Chest Of Drawers',
#   'listened_at': datetime.datetime(2025, 5, 1, 13, 38, 28, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ulla',
#   'track_name': 'Look Or Look Away',
#   'listened_at': datetime.datetime(2025, 5, 1, 13, 35, 38, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ulla',
#   'track_name': 'Aware Of Something',
#   'listened_at': datetime.datetime(2025, 5, 1, 13, 30, 41, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bon Iver',
#   'track_name': "I'll Be There",
#   'listened_at': datetime.datetime(2025, 5, 1, 13, 26, 36, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bon Iver',
#   'track_name': 'From',
#   'listened_at': datetime.datetime(2025, 5, 1, 13, 23, 1, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bon Iver',
#   'track_name': 'Day One',
#   'listened_at': datetime.datetime(2025, 5, 1, 13, 20, 40, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ulla',
#   'track_name': 'Aware Of Something',
#   'listened_at': datetime.datetime(2025, 5, 1, 12, 38, 11, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'GPF',
#   'track_name': 'Broccoli Fuck',
#   'listened_at': datetime.datetime(2025, 5, 1, 12, 34, 37, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Fjaak',
#   'track_name': 'Redemption',
#   'listened_at': datetime.datetime(2025, 5, 1, 12, 29, 13, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vieze Asbak',
#   'track_name': 'GET THE FUCK OUT',
#   'listened_at': datetime.datetime(2025, 5, 1, 12, 26, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'WTCHCRFT',
#   'track_name': 'FCKN RELAX',
#   'listened_at': datetime.datetime(2025, 5, 1, 12, 20, 28, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Amelie Lens',
#   'track_name': 'Higher - Fjaak Remix',
#   'listened_at': datetime.datetime(2025, 5, 1, 12, 15, 24, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dikke Baap',
#   'track_name': "IK TRIP 'M - Dimitri K Remix",
#   'listened_at': datetime.datetime(2025, 5, 1, 12, 13, 2, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Natte Visstick',
#   'track_name': 'In De Tram',
#   'listened_at': datetime.datetime(2025, 5, 1, 12, 10, 58, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'MarcelDune',
#   'track_name': 'Distorted Perception',
#   'listened_at': datetime.datetime(2025, 5, 1, 12, 5, 58, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vieze Asbak',
#   'track_name': 'CANT SAY SHIT',
#   'listened_at': datetime.datetime(2025, 5, 1, 12, 2, 54, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Gia Margaret',
#   'track_name': 'apathy',
#   'listened_at': datetime.datetime(2025, 5, 1, 11, 54, 1, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Aphex Twin',
#   'track_name': 'Digeridoo',
#   'listened_at': datetime.datetime(2025, 5, 1, 11, 52, 48, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dijon',
#   'track_name': "Nico's Red Truck",
#   'listened_at': datetime.datetime(2025, 5, 1, 11, 48, 57, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '1tbsp',
#   'track_name': 'Rush (Missing Out On Me)',
#   'listened_at': datetime.datetime(2025, 5, 1, 11, 45, 40, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lorde',
#   'track_name': 'What Was That',
#   'listened_at': datetime.datetime(2025, 5, 1, 11, 42, 37, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '1tbsp',
#   'track_name': 'Moth Love',
#   'listened_at': datetime.datetime(2025, 5, 1, 11, 39, 15, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Playboi Carti',
#   'track_name': 'HBA',
#   'listened_at': datetime.datetime(2025, 5, 1, 10, 23, 53, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lorde',
#   'track_name': 'What Was That',
#   'listened_at': datetime.datetime(2025, 5, 1, 10, 19, 56, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '1tbsp',
#   'track_name': 'Moth Love',
#   'listened_at': datetime.datetime(2025, 5, 1, 10, 17, 47, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Gia Margaret',
#   'track_name': 'apathy',
#   'listened_at': datetime.datetime(2025, 5, 1, 10, 12, 55, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Astrid Sonne',
#   'track_name': 'Withdrawal',
#   'listened_at': datetime.datetime(2025, 5, 1, 10, 10, 54, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Josiah Steinbrick',
#   'track_name': 'House Tears',
#   'listened_at': datetime.datetime(2025, 5, 1, 10, 8, 44, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Jeremiah Chiu',
#   'track_name': 'In Åland Air',
#   'listened_at': datetime.datetime(2025, 5, 1, 10, 5, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Carmen Villain',
#   'track_name': 'Agua Azul',
#   'listened_at': datetime.datetime(2025, 5, 1, 10, 0, 11, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mk.gee',
#   'track_name': 'Are You Looking Up',
#   'listened_at': datetime.datetime(2025, 5, 1, 9, 56, 7, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Cymande',
#   'track_name': 'Mighty Heavy Load',
#   'listened_at': datetime.datetime(2025, 5, 1, 9, 50, 56, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ludwig Göransson',
#   'track_name': 'Can You Hear the Music',
#   'listened_at': datetime.datetime(2025, 5, 1, 9, 38, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Aphex Twin',
#   'track_name': 'Digeridoo',
#   'listened_at': datetime.datetime(2025, 5, 1, 9, 27, 16, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Fjaak',
#   'track_name': 'Redemption',
#   'listened_at': datetime.datetime(2025, 5, 1, 9, 16, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Amelie Lens',
#   'track_name': 'Higher - Fjaak Remix',
#   'listened_at': datetime.datetime(2025, 5, 1, 9, 11, 26, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Skrillex',
#   'track_name': 'ZEET NOISE',
#   'listened_at': datetime.datetime(2025, 5, 1, 9, 9, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dikke Baap',
#   'track_name': "IK TRIP 'M - Dimitri K Remix",
#   'listened_at': datetime.datetime(2025, 5, 1, 9, 6, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Natte Visstick',
#   'track_name': 'In De Tram',
#   'listened_at': datetime.datetime(2025, 5, 1, 9, 5, 6, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'WTCHCRFT',
#   'track_name': 'Creedooo',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 56, 35, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vieze Asbak',
#   'track_name': 'TIMMERCLUB - SLVL Grenade Kick Edit',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 56, 35, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'WTCHCRFT',
#   'track_name': 'Creedooo',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 51, 24, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vieze Asbak',
#   'track_name': 'Lekkere Boterham',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 46, 30, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'James K',
#   'track_name': 'Ether',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 42, 15, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Laurel Halo',
#   'track_name': 'You Burn Me',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 41, 6, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sofie Birch',
#   'track_name': 'Calibrating Senses',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 37, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dylan Henner',
#   'track_name': "We're So Young That We'll Never Grow Old",
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 37, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dylan Henner',
#   'track_name': "We're So Young That We'll Never Grow Old",
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 30, 45, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yamaneko',
#   'track_name': 'Royal Beluga Comfort Zone',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 26, 48, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Carmen Villain',
#   'track_name': 'Only Love From Now On (with Johanna Scheie Orellana)',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 23, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Aya',
#   'track_name': 'The Petard is my Hoister',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 23, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Carmen Villain',
#   'track_name': 'Only Love From Now On (with Johanna Scheie Orellana)',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 14, 58, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Slow Attack Ensemble',
#   'track_name': 'Everything Turns Black to Blue',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 10, 57, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Elori Saxl',
#   'track_name': 'Wave I',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 8, 24, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Carmen Villain',
#   'track_name': 'Portals',
#   'listened_at': datetime.datetime(2025, 5, 1, 8, 4, 3, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ulla',
#   'track_name': 'Aware Of Something',
#   'listened_at': datetime.datetime(2025, 5, 1, 7, 59, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kaitlyn Aurelia Smith',
#   'track_name': 'Moon In Your Eye',
#   'listened_at': datetime.datetime(2025, 5, 1, 7, 56, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lorn',
#   'track_name': 'Acid Rain',
#   'listened_at': datetime.datetime(2025, 5, 1, 7, 53, 57, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'SMERZ',
#   'track_name': 'Versace strings',
#   'listened_at': datetime.datetime(2025, 5, 1, 7, 51, 53, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Astrid Sonne',
#   'track_name': 'Moderato',
#   'listened_at': datetime.datetime(2025, 5, 1, 7, 47, 55, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Huerco S.',
#   'track_name': 'A Sea of Love',
#   'listened_at': datetime.datetime(2025, 5, 1, 7, 40, 38, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bladee',
#   'track_name': 'St George the Martyr',
#   'listened_at': datetime.datetime(2025, 5, 1, 7, 29, 41, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bladee',
#   'track_name': 'Ask Jade',
#   'listened_at': datetime.datetime(2025, 5, 1, 7, 26, 59, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'EQ',
#   'track_name': 'EQetamine',
#   'listened_at': datetime.datetime(2025, 5, 1, 7, 23, 17, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'EQ',
#   'track_name': 'EQetamine',
#   'listened_at': datetime.datetime(2025, 5, 1, 6, 29, 49, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ecco2K',
#   'track_name': 'Amygdala',
#   'listened_at': datetime.datetime(2025, 4, 30, 19, 42, 54, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Caroline Polachek',
#   'track_name': 'Dang',
#   'listened_at': datetime.datetime(2025, 4, 30, 18, 19, 25, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '1017 ALYX 9SM',
#   'track_name': 'Famous Last Words (An Ode to Eaters)',
#   'listened_at': datetime.datetime(2025, 4, 30, 18, 16, 2, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'coldoutlay',
#   'track_name': 'Saving Me',
#   'listened_at': datetime.datetime(2025, 4, 30, 18, 12, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dijon',
#   'track_name': 'Sweet Thing',
#   'listened_at': datetime.datetime(2025, 4, 30, 18, 9, 37, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Gæste Gutter',
#   'track_name': 'Bergen freestyle',
#   'listened_at': datetime.datetime(2025, 4, 30, 18, 7, 47, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dijon',
#   'track_name': 'Rodeo Clown',
#   'listened_at': datetime.datetime(2025, 4, 30, 18, 4, 23, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dijon',
#   'track_name': 'Violence)',
#   'listened_at': datetime.datetime(2025, 4, 30, 18, 1, 51, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dijon',
#   'track_name': 'Talk Down',
#   'listened_at': datetime.datetime(2025, 4, 30, 18, 1, 51, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dijon',
#   'track_name': 'Violence)',
#   'listened_at': datetime.datetime(2025, 4, 30, 17, 58, 25, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dijon',
#   'track_name': 'Many Times',
#   'listened_at': datetime.datetime(2025, 4, 30, 17, 56, 17, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dijon',
#   'track_name': "Nico's Red Truck",
#   'listened_at': datetime.datetime(2025, 4, 30, 17, 52, 8, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dijon',
#   'track_name': 'The Dress',
#   'listened_at': datetime.datetime(2025, 4, 30, 17, 49, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'EQ',
#   'track_name': 'Boytoy',
#   'listened_at': datetime.datetime(2025, 4, 30, 17, 47, 30, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dutch Zebra',
#   'track_name': 'Werken Voor Je Geld',
#   'listened_at': datetime.datetime(2025, 4, 30, 17, 46, 7, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bladee',
#   'track_name': 'Ask Jade',
#   'listened_at': datetime.datetime(2025, 4, 30, 15, 41, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kettama',
#   'track_name': 'It Gets Better - Edit',
#   'listened_at': datetime.datetime(2025, 4, 30, 15, 32, 57, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Snow Strippers',
#   'track_name': 'Under Your Spell',
#   'listened_at': datetime.datetime(2025, 4, 30, 14, 24, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Snow Strippers',
#   'track_name': "So What If I'm A Freak",
#   'listened_at': datetime.datetime(2025, 4, 30, 14, 22, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'bassvictim',
#   'track_name': 'With You',
#   'listened_at': datetime.datetime(2025, 4, 30, 14, 19, 20, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Brutalismus 3000',
#   'track_name': '9mm',
#   'listened_at': datetime.datetime(2025, 4, 30, 14, 15, 23, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Jane Remover',
#   'track_name': 'Psychoboost feat danny brown',
#   'listened_at': datetime.datetime(2025, 4, 30, 14, 9, 57, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '2hollis',
#   'track_name': 'flash',
#   'listened_at': datetime.datetime(2025, 4, 30, 14, 7, 14, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Cyberbully Mom Club',
#   'track_name': "philadelphia, don't you haunt me",
#   'listened_at': datetime.datetime(2025, 4, 30, 14, 4, 42, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'bassvictim',
#   'track_name': 'L-ON-D-ON',
#   'listened_at': datetime.datetime(2025, 4, 30, 14, 4, 42, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'bassvictim',
#   'track_name': 'L-ON-D-ON',
#   'listened_at': datetime.datetime(2025, 4, 30, 14, 1, 34, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '1tbsp',
#   'track_name': 'Rush (Missing Out On Me)',
#   'listened_at': datetime.datetime(2025, 4, 30, 13, 59, 37, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Enjoy',
#   'track_name': 'Drift',
#   'listened_at': datetime.datetime(2025, 4, 30, 13, 56, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Jane Remover',
#   'track_name': 'Fadeoutz',
#   'listened_at': datetime.datetime(2025, 4, 30, 13, 53, 2, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vegyn',
#   'track_name': 'Halo Flip',
#   'listened_at': datetime.datetime(2025, 4, 30, 13, 46, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vegyn',
#   'track_name': 'Makeshift Tourniquet',
#   'listened_at': datetime.datetime(2025, 4, 30, 13, 40, 51, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sam Gellaitry',
#   'track_name': 'Thinking',
#   'listened_at': datetime.datetime(2021, 12, 18, 10, 55, 8, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vegyn',
#   'track_name': 'Last Night I Dreamt I was Alone',
#   'listened_at': datetime.datetime(2025, 4, 30, 13, 37, 24, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vegyn',
#   'track_name': 'Time Well Spent',
#   'listened_at': datetime.datetime(2025, 4, 30, 13, 34, 24, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'DJ Billybool',
#   'track_name': 'BLOMSTERTID',
#   'listened_at': datetime.datetime(2025, 4, 30, 13, 31, 47, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'brothel in belize',
#   'track_name': 'Electronica',
#   'listened_at': datetime.datetime(2025, 4, 30, 13, 29, 45, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yung Lean',
#   'track_name': 'Hennessy & Sailor Moon',
#   'listened_at': datetime.datetime(2021, 12, 20, 6, 32, 21, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yung Lean',
#   'track_name': 'Red Bottom Sky',
#   'listened_at': datetime.datetime(2021, 12, 20, 6, 27, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kučka',
#   'track_name': 'Honey',
#   'listened_at': datetime.datetime(2021, 12, 20, 6, 19, 16, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lancey Foux',
#   'track_name': 'RESPECT',
#   'listened_at': datetime.datetime(2021, 12, 20, 6, 17, 26, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Hans Zimmer',
#   'track_name': 'Tick-Tock',
#   'listened_at': datetime.datetime(2021, 12, 19, 20, 13, 1, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'John Maus',
#   'track_name': 'Bennington (2007)',
#   'listened_at': datetime.datetime(2021, 12, 19, 19, 36, 13, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bill Evans Trio',
#   'track_name': 'My Foolish Heart',
#   'listened_at': datetime.datetime(2021, 12, 19, 17, 25, 10, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bill Evans Trio',
#   'track_name': 'Porgy (I Loves You Porgy) - Outtake',
#   'listened_at': datetime.datetime(2021, 12, 19, 17, 18, 1, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ross From Friends',
#   'track_name': 'Bootman',
#   'listened_at': datetime.datetime(2021, 12, 19, 17, 11, 33, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'The Smiths',
#   'track_name': 'There Is a Light That Never Goes Out - 2011 Remaster',
#   'listened_at': datetime.datetime(2021, 12, 19, 17, 6, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ross From Friends',
#   'track_name': 'Crimson',
#   'listened_at': datetime.datetime(2021, 12, 19, 15, 37, 33, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'The Strokes',
#   'track_name': 'Reptilia',
#   'listened_at': datetime.datetime(2021, 12, 19, 15, 33, 51, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kučka',
#   'track_name': 'Honey',
#   'listened_at': datetime.datetime(2021, 12, 19, 15, 31, 59, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'kurtains',
#   'track_name': 'crowbars',
#   'listened_at': datetime.datetime(2021, 12, 19, 14, 1, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'ICEBIRDS',
#   'track_name': 'I Got It',
#   'listened_at': datetime.datetime(2021, 12, 19, 13, 42, 59, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Flume',
#   'track_name': 'Rushing Back',
#   'listened_at': datetime.datetime(2021, 12, 19, 13, 38, 33, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'SOUDIERE',
#   'track_name': 'Out the Snow',
#   'listened_at': datetime.datetime(2021, 12, 19, 13, 35, 16, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Flume',
#   'track_name': 'MUD',
#   'listened_at': datetime.datetime(2021, 12, 19, 13, 33, 47, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Stevie Dinner',
#   'track_name': 'Naturally',
#   'listened_at': datetime.datetime(2021, 12, 19, 13, 30, 41, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '24hrs',
#   'track_name': 'Regina George',
#   'listened_at': datetime.datetime(2021, 12, 19, 13, 28, 7, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'KAYTRANADA',
#   'track_name': 'Intimidated (feat. H.E.R.)',
#   'listened_at': datetime.datetime(2021, 12, 19, 13, 23, 56, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'starry cat',
#   'track_name': 'happiness',
#   'listened_at': datetime.datetime(2021, 12, 19, 13, 23, 54, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'starry cat',
#   'track_name': 'happiness',
#   'listened_at': datetime.datetime(2021, 12, 19, 12, 26, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'The Strokes',
#   'track_name': 'Reptilia',
#   'listened_at': datetime.datetime(2021, 12, 19, 12, 22, 16, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lebanon Hanover',
#   'track_name': 'Gallowdance',
#   'listened_at': datetime.datetime(2021, 12, 19, 11, 37, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Da-P',
#   'track_name': 'Ms. Communication',
#   'listened_at': datetime.datetime(2021, 12, 19, 11, 37, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Beach Bunny',
#   'track_name': 'Promises',
#   'listened_at': datetime.datetime(2021, 12, 19, 11, 17, 6, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Prince',
#   'track_name': 'Kiss',
#   'listened_at': datetime.datetime(2021, 12, 19, 11, 12, 45, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'The Cure',
#   'track_name': 'Just Like Heaven',
#   'listened_at': datetime.datetime(2021, 12, 19, 11, 9, 14, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'glaive',
#   'track_name': 'dnd',
#   'listened_at': datetime.datetime(2021, 12, 19, 10, 30, 58, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dominic Fike',
#   'track_name': 'She Wants My Money',
#   'listened_at': datetime.datetime(2021, 12, 19, 10, 28, 45, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'lovesickxo',
#   'track_name': 'mixed signals',
#   'listened_at': datetime.datetime(2021, 12, 19, 10, 23, 54, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mixed Matches',
#   'track_name': 'cicatriz',
#   'listened_at': datetime.datetime(2021, 12, 19, 10, 20, 58, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lil Lucifer',
#   'track_name': 'Fell in Love',
#   'listened_at': datetime.datetime(2021, 12, 19, 10, 19, 19, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Teen Suicide',
#   'track_name': 'bad news',
#   'listened_at': datetime.datetime(2021, 12, 19, 10, 16, 30, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Joji',
#   'track_name': 'Worldstar Money (Interlude)',
#   'listened_at': datetime.datetime(2021, 12, 19, 10, 14, 24, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'The Mills Brothers',
#   'track_name': 'You Always Hurt The One You Love',
#   'listened_at': datetime.datetime(2021, 12, 19, 10, 9, 56, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Al Bowlly',
#   'track_name': "You're As Pretty As A Picture",
#   'listened_at': datetime.datetime(2021, 12, 19, 10, 6, 59, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Chet Baker',
#   'track_name': "It's Always You - Vocal Version",
#   'listened_at': datetime.datetime(2021, 12, 19, 10, 0, 53, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Tommy Dorsey',
#   'track_name': 'Polka Dots And Moonbeams',
#   'listened_at': datetime.datetime(2021, 12, 19, 9, 57, 34, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Young Doski',
#   'track_name': 'Medusa',
#   'listened_at': datetime.datetime(2021, 12, 19, 9, 56, 27, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'KAYTRANADA',
#   'track_name': 'Intimidated (feat. H.E.R.)',
#   'listened_at': datetime.datetime(2021, 12, 19, 9, 51, 8, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Carwash',
#   'track_name': 'striptease',
#   'listened_at': datetime.datetime(2021, 12, 19, 9, 21, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bladee',
#   'track_name': 'Ebay',
#   'listened_at': datetime.datetime(2021, 12, 19, 9, 17, 46, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Elliott Smith',
#   'track_name': 'Say Yes',
#   'listened_at': datetime.datetime(2021, 12, 19, 9, 15, 27, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Nate Sib',
#   'track_name': 'down',
#   'listened_at': datetime.datetime(2024, 1, 11, 5, 39, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yung Lean',
#   'track_name': 'Ginseng Strip 2002',
#   'listened_at': datetime.datetime(2021, 12, 18, 21, 14, 46, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bladee',
#   'track_name': 'egobaby',
#   'listened_at': datetime.datetime(2021, 12, 18, 20, 45, 42, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Gunna',
#   'track_name': 'YSL (feat. Playboi Carti)',
#   'listened_at': datetime.datetime(2021, 12, 18, 18, 32, 36, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '100 gecs',
#   'track_name': '800db cloud (Ricco Harver Remix)',
#   'listened_at': datetime.datetime(2021, 12, 18, 18, 30, 52, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Playboi Carti',
#   'track_name': 'Sky',
#   'listened_at': datetime.datetime(2021, 12, 18, 18, 27, 38, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kučka',
#   'track_name': 'Honey - Medasin Remix',
#   'listened_at': datetime.datetime(2021, 12, 18, 18, 23, 49, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Playboi Carti',
#   'track_name': 'Rockstar Made',
#   'listened_at': datetime.datetime(2021, 12, 18, 18, 7, 21, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Teen Suicide',
#   'track_name': 'Alex',
#   'listened_at': datetime.datetime(2021, 12, 18, 17, 17, 24, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'TV Girl',
#   'track_name': 'Daughter of a Cop',
#   'listened_at': datetime.datetime(2021, 12, 18, 17, 14, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'American Pleasure Club',
#   'track_name': 'all the lonely nights in your life',
#   'listened_at': datetime.datetime(2021, 12, 18, 17, 12, 8, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Drippin So Pretty',
#   'track_name': 'blood on my jacket, Pt. 2',
#   'listened_at': datetime.datetime(2021, 12, 18, 16, 45, 10, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'snctm.',
#   'track_name': 'Omokage.',
#   'listened_at': datetime.datetime(2021, 12, 18, 16, 32, 52, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Clairo',
#   'track_name': '4EVER',
#   'listened_at': datetime.datetime(2021, 12, 18, 15, 15, 38, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Rina Sawayama',
#   'track_name': 'Comme des Garçons (Like the Boys)',
#   'listened_at': datetime.datetime(2021, 12, 18, 15, 13, 24, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dominic Fike',
#   'track_name': 'She Wants My Money',
#   'listened_at': datetime.datetime(2021, 12, 18, 15, 13, 23, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Rina Sawayama',
#   'track_name': 'Comme des Garçons (Like the Boys)',
#   'listened_at': datetime.datetime(2021, 12, 18, 15, 10, 20, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lorde',
#   'track_name': 'Perfect Places',
#   'listened_at': datetime.datetime(2021, 12, 18, 15, 6, 36, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bladee',
#   'track_name': 'Girls just want to have fun',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 50, 25, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Pikekyss',
#   'track_name': 'Berlin',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 47, 16, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kaja Gunnufsen',
#   'track_name': 'Sukkerspinn',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 43, 16, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Marinelli',
#   'track_name': 'Candy Cigarette',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 40, 39, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '100 gecs',
#   'track_name': 'gec 2 Ü (Remix) [feat. Dorian Electra]',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 37, 51, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Thundercat',
#   'track_name': 'Funny Thing',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 35, 53, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Montell Fish',
#   'track_name': 'talk 2 me',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 30, 23, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bon Iver',
#   'track_name': 'Beach Baby',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 27, 42, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Teen Suicide',
#   'track_name': 'haunt me (x 3)',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 24, 48, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mac DeMarco',
#   'track_name': 'Moonlight on the River',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 18, 19, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Joy Again',
#   'track_name': 'Looking Out For You',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 15, 17, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Clairo',
#   'track_name': 'Blouse',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 12, 1, tzinfo=datetime.timezone.utc)},
#  {'artist_name': "Her's",
#   'track_name': 'What Once Was',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 7, 44, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Austin Farwell',
#   'track_name': 'New Home',
#   'listened_at': datetime.datetime(2021, 12, 18, 14, 4, 51, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Austin Farwell',
#   'track_name': 'New Home',
#   'listened_at': datetime.datetime(2021, 12, 18, 12, 23, 59, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lucki',
#   'track_name': '2019',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 47, 5, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Got Rich',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 45, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Stayëd tha same',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 42, 32, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Turban',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 39, 57, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Cmon',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 38, 13, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Big Stonëz',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 35, 25, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Sorry Bout That',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 32, 20, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Mad bout that',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 28, 48, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Gët Busy',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 26, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Got Rich',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 24, 6, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Stayëd tha same',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 21, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Turban',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 16, 39, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kučka',
#   'track_name': 'Honey - Medasin Remix',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 9, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kučka',
#   'track_name': 'Honey',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 6, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lancey Foux',
#   'track_name': 'RESPECT',
#   'listened_at': datetime.datetime(2021, 12, 18, 11, 4, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'San Holo',
#   'track_name': 'Honest',
#   'listened_at': datetime.datetime(2021, 12, 18, 10, 59, 15, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Semiset',
#   'track_name': 'Space',
#   'listened_at': datetime.datetime(2021, 6, 5, 11, 23, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vindata',
#   'track_name': 'Spirals',
#   'listened_at': datetime.datetime(2021, 12, 18, 10, 52, 25, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Flume',
#   'track_name': 'Tiny Cities',
#   'listened_at': datetime.datetime(2021, 12, 18, 10, 48, 28, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yoste',
#   'track_name': 'Chihiro',
#   'listened_at': datetime.datetime(2021, 12, 18, 10, 44, 54, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'San Holo',
#   'track_name': 'We Rise',
#   'listened_at': datetime.datetime(2021, 12, 18, 10, 40, 28, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'glaive',
#   'track_name': 'dnd',
#   'listened_at': datetime.datetime(2021, 12, 18, 10, 38, 11, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Cmon',
#   'listened_at': datetime.datetime(2021, 12, 18, 10, 36, 51, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'meat computer',
#   'track_name': 'i feel like a dog',
#   'listened_at': datetime.datetime(2025, 3, 12, 14, 43, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'MJ Lenderman',
#   'track_name': 'Someone Get The Grill Out Of The Rain',
#   'listened_at': datetime.datetime(2025, 3, 12, 14, 39, 14, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dutch Interior',
#   'track_name': 'Light of Becoming',
#   'listened_at': datetime.datetime(2025, 3, 12, 14, 35, 32, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Floatie',
#   'track_name': 'Castleman',
# ...
#   'listened_at': datetime.datetime(2023, 10, 28, 9, 43, 28, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '1017 ALYX 9SM',
#   'track_name': 'Alyx Assassin (feat. NGeeYL)',
#   'listened_at': datetime.datetime(2023, 10, 28, 9, 41, 2, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'louke man',
#   'track_name': 'Took a Turn',
#   'listened_at': datetime.datetime(2023, 10, 28, 9, 38, 46, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Frits Wentink',
#   'track_name': 'Chad Brothers',
#   'listened_at': datetime.datetime(2023, 10, 28, 9, 32, 59, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bladee',
#   'track_name': 'Decay',
#   'listened_at': datetime.datetime(2023, 10, 28, 9, 18, 18, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '1017 ALYX 9SM',
#   'track_name': 'Famous Last Words (An Ode to Eaters)',
#   'listened_at': datetime.datetime(2023, 10, 28, 9, 7, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yung Lean',
#   'track_name': 'Bullets',
#   'listened_at': datetime.datetime(2023, 10, 28, 9, 3, 48, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Pretty Sick',
#   'track_name': 'Dumb',
#   'listened_at': datetime.datetime(2023, 10, 28, 8, 56, 54, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'New Order',
#   'track_name': 'Ecstacy - 2015 Remaster',
#   'listened_at': datetime.datetime(2023, 10, 28, 8, 56, 54, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Pretty Sick',
#   'track_name': 'Dumb',
#   'listened_at': datetime.datetime(2023, 10, 28, 8, 53, 58, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Pretty Sick',
#   'track_name': 'Undress',
#   'listened_at': datetime.datetime(2023, 10, 28, 8, 49, 58, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Pretty Sick',
#   'track_name': 'Superstar',
#   'listened_at': datetime.datetime(2023, 10, 28, 8, 46, 19, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Frits Wentink',
#   'track_name': 'Dwayne Young',
#   'listened_at': datetime.datetime(2023, 12, 8, 15, 38, 59, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sunflwr',
#   'track_name': 'fly already',
#   'listened_at': datetime.datetime(2023, 12, 8, 15, 34, 55, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '1tbsp',
#   'track_name': 'Calico',
#   'listened_at': datetime.datetime(2023, 12, 8, 15, 30, 3, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sunflwr',
#   'track_name': 'you got your own thing going',
#   'listened_at': datetime.datetime(2023, 12, 8, 15, 26, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'DJ Seinfeld',
#   'track_name': 'Stargard - Mixed',
#   'listened_at': datetime.datetime(2023, 12, 8, 15, 24, 19, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Logic1000',
#   'track_name': 'YourLove',
#   'listened_at': datetime.datetime(2023, 12, 8, 15, 21, 27, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vegyn',
#   'track_name': 'Mushroom Abolitionist',
#   'listened_at': datetime.datetime(2023, 12, 8, 15, 16, 42, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Taiki Nulight',
#   'track_name': 'Through Glass',
#   'listened_at': datetime.datetime(2023, 12, 8, 15, 14, 5, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sweely',
#   'track_name': 'House is Home',
#   'listened_at': datetime.datetime(2023, 12, 8, 15, 8, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ruze',
#   'track_name': 'Hardwire',
#   'listened_at': datetime.datetime(2023, 12, 8, 15, 0, 40, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Youandewan',
#   'track_name': 'Left On Lucy',
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 54, 1, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mixed Matches',
#   'track_name': 'Jesse',
#   'listened_at': datetime.datetime(2022, 8, 31, 16, 18, 44, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Nate Sib',
#   'track_name': 'down',
#   'listened_at': datetime.datetime(2024, 1, 9, 12, 26, 42, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'SURF GANG',
#   'track_name': '24 hrs P2',
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 45, 57, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ecco2K',
#   'track_name': 'Western Union',
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 43, 56, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Bladee',
#   'track_name': 'Girls just want to have fun',
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 41, 41, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Drake',
#   'track_name': 'Rich Baby Daddy (feat. Sexyy Red & SZA)',
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 36, 21, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Night Lovell',
#   'track_name': 'SUCKS TO BE YOU :/',
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 31, 41, tzinfo=datetime.timezone.utc)},
#  {'artist_name': "Ghost Town DJ's",
#   'track_name': "My Boo - Hitman's Club Mix",
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 30, 33, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Evian Christ',
#   'track_name': 'Yxguden',
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 26, 6, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Klaus Veen',
#   'track_name': 'Poison',
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 22, 55, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Kero Kero Bonito',
#   'track_name': 'Time Today',
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 20, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Charli xcx',
#   'track_name': 'Trophy',
#   'listened_at': datetime.datetime(2023, 12, 8, 14, 10, 59, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': 'BIPP',
#   'listened_at': datetime.datetime(2023, 12, 8, 11, 14, 26, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Eartheater',
#   'track_name': 'Supersoaker',
#   'listened_at': datetime.datetime(2023, 12, 8, 11, 11, 47, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Oklou',
#   'track_name': "god's chariots",
#   'listened_at': datetime.datetime(2023, 12, 8, 11, 8, 42, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Caroline Polachek',
#   'track_name': 'Hey Big Eyes - George Clanton Remix',
#   'listened_at': datetime.datetime(2023, 12, 8, 11, 5, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'FKA twigs',
#   'track_name': 'pamplemousse',
#   'listened_at': datetime.datetime(2023, 12, 8, 11, 3, 53, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'FKA twigs',
#   'track_name': 'pamplemousse',
#   'listened_at': datetime.datetime(2023, 12, 8, 11, 2, 14, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Charli xcx',
#   'track_name': 'anthems',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 59, 21, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': 'Infatuation - The Abyss',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 58, 21, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Eartheater',
#   'track_name': 'Mitosis',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 56, 42, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Arca',
#   'track_name': 'Time',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 53, 10, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Charli xcx',
#   'track_name': 'pink diamond',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 51, 5, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Planet 1999',
#   'track_name': 'Haze',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 50, 7, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': 'Whole New World/Pretend World',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 40, 59, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': 'Immaterial',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 37, 6, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': 'Pretending',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 31, 13, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': 'Not Okay',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 29, 25, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': 'Infatuation',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 24, 45, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': 'Is It Cold in the Water?',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 16, 20, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': 'Faceshopping',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 12, 22, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': 'Ponyboy',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 9, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sophie',
#   'track_name': "It's Okay to Cry",
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 5, 18, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Charli xcx',
#   'track_name': 'claws',
#   'listened_at': datetime.datetime(2023, 12, 8, 10, 1, 43, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Night Lovell',
#   'track_name': 'LIFE SUCKS SO WE FUCK (feat. ZillaKami)',
#   'listened_at': datetime.datetime(2023, 12, 8, 9, 41, 50, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Night Lovell',
#   'track_name': 'MORRISON',
#   'listened_at': datetime.datetime(2023, 12, 8, 9, 39, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Frank Ocean',
#   'track_name': 'Super Rich Kids',
#   'listened_at': datetime.datetime(2023, 12, 8, 6, 27, 30, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Baby Keem',
#   'track_name': 'The Hillbillies',
#   'listened_at': datetime.datetime(2023, 12, 8, 6, 23, 21, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Lebanon Hanover',
#   'track_name': 'Gallowdance',
#   'listened_at': datetime.datetime(2023, 12, 8, 6, 5, 49, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Björk',
#   'track_name': 'Oral',
#   'listened_at': datetime.datetime(2023, 12, 8, 5, 58, 47, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'FKA twigs',
#   'track_name': 'Two Weeks',
#   'listened_at': datetime.datetime(2023, 12, 8, 5, 54, 40, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'CASPIAN ROSE',
#   'track_name': 'Stay',
#   'listened_at': datetime.datetime(2023, 12, 8, 5, 51, 55, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Yeat',
#   'track_name': 'Talk',
#   'listened_at': datetime.datetime(2023, 12, 7, 17, 4, 5, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'The Kid LAROI',
#   'track_name': 'NOT FAIR (feat. Corbin)',
#   'listened_at': datetime.datetime(2023, 12, 7, 17, 1, 17, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Destroy Lonely',
#   'track_name': 'money & sex',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 56, 47, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Dom Corleo',
#   'track_name': 'Penthouse Shordy',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 54, 20, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Homixide Gang',
#   'track_name': 'MW5',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 51, 27, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Night Lovell',
#   'track_name': 'Lethal Presence',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 49, 5, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Harto Falión',
#   'track_name': '1doorcloses, 1dooropens',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 45, 27, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '1tbsp',
#   'track_name': 'Calico',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 45, 6, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sunflwr',
#   'track_name': 'you got your own thing going',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 30, 21, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'lungskull',
#   'track_name': '!?',
#   'listened_at': datetime.datetime(2024, 1, 9, 11, 36, 26, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Logic1000',
#   'track_name': 'YourLove',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 25, 48, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Vegyn',
#   'track_name': 'Mushroom Abolitionist',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 21, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Taiki Nulight',
#   'track_name': 'Through Glass',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 18, 27, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sweely',
#   'track_name': 'House is Home',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 12, 31, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Ruze',
#   'track_name': 'Hardwire',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 5, 1, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Youandewan',
#   'track_name': 'Left On Lucy',
#   'listened_at': datetime.datetime(2023, 12, 7, 16, 0, 17, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sweely',
#   'track_name': 'House is Home',
#   'listened_at': datetime.datetime(2023, 12, 7, 15, 52, 25, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Jadu Jadu',
#   'track_name': "i'll be your xtc",
#   'listened_at': datetime.datetime(2023, 12, 7, 15, 48, 3, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sunflwr',
#   'track_name': 'porco rosso',
#   'listened_at': datetime.datetime(2023, 12, 7, 15, 44, 23, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'DJ Tired',
#   'track_name': 'MIDNITE RIDE',
#   'listened_at': datetime.datetime(2023, 12, 7, 15, 40, 36, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'The Smiths',
#   'track_name': 'The Headmaster Ritual - 2011 Remaster',
#   'listened_at': datetime.datetime(2023, 12, 7, 14, 38, 33, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'The Jesus and Mary Chain',
#   'track_name': 'Just Like Honey',
#   'listened_at': datetime.datetime(2023, 12, 7, 14, 35, 28, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Mood J',
#   'track_name': 'NY Vibration',
#   'listened_at': datetime.datetime(2023, 12, 7, 14, 12, 49, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Chaos in the CBD',
#   'track_name': 'Trust Is Key',
#   'listened_at': datetime.datetime(2023, 12, 7, 14, 7, 9, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Four Tet',
#   'track_name': 'SW9 9SL',
#   'listened_at': datetime.datetime(2023, 12, 7, 13, 59, 13, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'DJ Planet Express',
#   'track_name': "More Than You'd Ever Wanna Know",
#   'listened_at': datetime.datetime(2023, 12, 7, 13, 54, 30, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Fouk',
#   'track_name': 'Coconuts',
#   'listened_at': datetime.datetime(2023, 12, 7, 13, 48, 2, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Black Loops',
#   'track_name': 'Higher',
#   'listened_at': datetime.datetime(2023, 12, 7, 13, 41, 55, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sunflwr',
#   'track_name': 'you got your own thing going',
#   'listened_at': datetime.datetime(2023, 12, 7, 13, 39, 16, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sunflwr',
#   'track_name': 'fly already',
#   'listened_at': datetime.datetime(2023, 12, 7, 13, 35, 12, tzinfo=datetime.timezone.utc)},
#  {'artist_name': '⣎⡇ꉺლ༽இ•̛)ྀ◞ ༎ຶ ༽ৣৢ؞ৢ؞ؖ ꉺლ',
#   'track_name': 'ʅ͡͡͡͡͡͡͡͡͡͡͡(ƟӨ)ʃ͡͡͡͡͡͡͡͡͡͡ ꐑ(ཀ ඊູ ఠీੂ೧ູ࿃ूੂ✧✧✧✧✧✧ළඕั࿃ूੂ࿃ूੂ',
#   'listened_at': datetime.datetime(2023, 12, 7, 13, 30, 34, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Black Loops',
#   'track_name': 'Suki',
#   'listened_at': datetime.datetime(2023, 12, 7, 13, 23, 54, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Sunflwr',
#   'track_name': 'porco rosso',
#   'listened_at': datetime.datetime(2023, 12, 7, 13, 20, 8, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'Harto Falión',
#   'track_name': '1doorcloses, 1dooropens',
#   'listened_at': datetime.datetime(2023, 12, 7, 12, 22, 47, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'SURF GANG',
#   'track_name': 'Cruel Summer',
#   'listened_at': datetime.datetime(2023, 12, 7, 12, 21, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'brakence',
#   'track_name': 'teeth',
#   'listened_at': datetime.datetime(2023, 12, 7, 11, 59, 4, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'aldrch',
#   'track_name': 'watercolor puddles',
#   'listened_at': datetime.datetime(2023, 12, 7, 11, 56, 23, tzinfo=datetime.timezone.utc)},
#  {'artist_name': 'brakence',
#   'track_name': 'venus fly trap',
#   'listened_at': datetime.datetime(2023, 12, 7, 11, 56, 22, tzinfo=datetime.timezone.utc)},
#  ...]

# %%
df_history = pd.DataFrame.from_records(listening_history)
df_history = df_history.sort_values("listened_at", ascending=False)
df_history.head()
# Out:
#             artist_name                     track_name  \
# 26947            Oli XL                CONSPIRACY GIRL
# 26948          EsDeeKid                         4 Raws
# 26949  The Crying Nudes                        joyride
# 26950      Skin On Skin                Let Me Say This
# 26951      Lover's Skit  No Te Metas - Sassy 009 Remix
#
#                     listened_at
# 26947 2025-12-17 10:03:44+00:00
# 26948 2025-12-17 10:01:17+00:00
# 26949 2025-12-17 09:59:40+00:00
# 26950 2025-12-17 09:55:27+00:00
# 26951 2025-12-17 09:52:29+00:00

# %%
from datetime import datetime, timezone
year = 2025
filter_date = datetime(year, 1, 1, tzinfo=timezone.utc)
df_2025 = df_history[df_history.listened_at >= filter_date]
df_2025.head()
# Out:
#             artist_name                     track_name  \
# 26947            Oli XL                CONSPIRACY GIRL
# 26948          EsDeeKid                         4 Raws
# 26949  The Crying Nudes                        joyride
# 26950      Skin On Skin                Let Me Say This
# 26951      Lover's Skit  No Te Metas - Sassy 009 Remix
#
#                     listened_at
# 26947 2025-12-17 10:03:44+00:00
# 26948 2025-12-17 10:01:17+00:00
# 26949 2025-12-17 09:59:40+00:00
# 26950 2025-12-17 09:55:27+00:00
# 26951 2025-12-17 09:52:29+00:00

# %% [markdown]
# ## Top artists played
#
# Stacked barplot with top 20 artists. The stacks are their most played songs etc.

# %%
df_top_artists = df_2025.value_counts("artist_name").iloc[:20]
df_top_artists.head()
# Out:
# artist_name
# Bladee          393
# Dean Blunt      359
# Vegyn           288
# Astrid Sonne    277
# SMERZ           274
# Name: count, dtype: int64

# %%
df_top_artists_2025 = df_2025.query(f"artist_name == {df_top_artists.index.tolist()}")
most_played_artists = df_top_artists_2025[["artist_name", "track_name"]].groupby([ "artist_name", "track_name" ], as_index=False).agg(num_plays=("track_name", "count"))
# most_played_artists["artist_total"] = most_played_artists.groupby("artist_name")["num_plays"].transform("sum")
# most_played_artists = most_played_artists.sort_values(["artist_total", "num_plays"], ascending=[ False, True ])
most_played_artists
# Out:
#     artist_name                 track_name  num_plays
# 0       2hollis                    2iss025          1
# 1       2hollis                     all 2s          1
# 2       2hollis                  beginning          1
# 3       2hollis                       burn          2
# 4       2hollis                       cope          2
# ..          ...                        ...        ...
# 811  bassvictim  Walk Hard (G string edit)          1
# 812  bassvictim                    Welcome          9
# 813  bassvictim                   With You         11
# 814  bassvictim             Wolves Howling          4
# 815  bassvictim              forever salty          9
#
# [816 rows x 3 columns]

# %%
import plotly.express as px

fig = px.bar(most_played_artists, y="artist_name", x="num_plays", color="num_plays", hover_name="track_name", color_continuous_scale="blugrn_r")
fig.update_layout(showlegend=False)
fig.update_yaxes(autorange="reversed")

# %% [markdown]
# ## Top Songs

# %%
df_top_songs = df_2025.value_counts("track_name")
df_top_songs
# Out:
# track_name
# 5                 50
# flash             48
# bluey vuitton     44
# Poplife           43
# Woman Lake        43
#                   ..
# LA to BCN          1
# LICK               1
# LIEK "S__T"        1
# LIGHT'N UP         1
# Mildred Pierce     1
# Name: count, Length: 4867, dtype: int64

# %%
df_top_tracks_2025 = df_2025.query(f"track_name == {df_top_songs.index.tolist()}")
most_played_songs = df_top_tracks_2025[["artist_name", "track_name"]].groupby([ "artist_name", "track_name" ], as_index=False).agg(num_plays=("track_name", "count"))
most_played_songs = most_played_songs.sort_values(["num_plays"], ascending=False).reset_index(drop=True)
most_played_songs["y_labels"] = most_played_songs["artist_name"] + " | " + most_played_songs["track_name"]
most_played_songs
# Out:
#        artist_name         track_name  num_plays  \
# 0       Dean Blunt                  5         50
# 1          2hollis              flash         48
# 2       Babyfather      bluey vuitton         44
# 3             umru            Poplife         43
# 4          Snuggle         Woman Lake         43
# ...            ...                ...        ...
# 4978    Disclosure  Omen - Radio Edit          1
# 4979      New York                you          1
# 4980         Niamh   The Golden Ratio          1
# 4981  Dire Straits   Sultans of Swing          1
# 4982          Lorn            Oxbow B          1
#
#                              y_labels
# 0                      Dean Blunt | 5
# 1                     2hollis | flash
# 2          Babyfather | bluey vuitton
# 3                      umru | Poplife
# 4                Snuggle | Woman Lake
# ...                               ...
# 4978   Disclosure | Omen - Radio Edit
# 4979                   New York | you
# 4980         Niamh | The Golden Ratio
# 4981  Dire Straits | Sultans of Swing
# 4982                   Lorn | Oxbow B
#
# [4983 rows x 4 columns]

# %%
fig_songs = px.bar(most_played_songs.iloc[:20], x="num_plays", y="y_labels", color="num_plays", hover_name="track_name", color_continuous_scale="blugrn_r")
fig_songs.update_layout(showlegend=False)
fig_songs.update_yaxes(autorange="reversed")
fig_songs

# %% [markdown]
# ## Listenership by month

# %%
df_2025
# Out:
#             artist_name                             track_name  \
# 26947            Oli XL                        CONSPIRACY GIRL
# 26948          EsDeeKid                                 4 Raws
# 26949  The Crying Nudes                                joyride
# 26950      Skin On Skin                        Let Me Say This
# 26951      Lover's Skit          No Te Metas - Sassy 009 Remix
# ...                 ...                                    ...
# 74699             Smino  Hoe-nouns (feat. Thundercat & reggie)
# 74700       underscores       Stupid (Can’t run from the urge)
# 74701    Snow Strippers                      We Both Suffocate
# 74702         Mutilator                      Can You Feel It?!
# 74703  Brutalismus 3000                           Europaträume
#
#                     listened_at
# 26947 2025-12-17 10:03:44+00:00
# 26948 2025-12-17 10:01:17+00:00
# 26949 2025-12-17 09:59:40+00:00
# 26950 2025-12-17 09:55:27+00:00
# 26951 2025-12-17 09:52:29+00:00
# ...                         ...
# 74699 2025-01-01 17:58:08+00:00
# 74700 2025-01-01 01:17:56+00:00
# 74701 2025-01-01 01:15:13+00:00
# 74702 2025-01-01 01:10:27+00:00
# 74703 2025-01-01 01:07:47+00:00
#
# [16718 rows x 3 columns]

# %%
df_monthly_dist = df_2025.groupby(df_2025.listened_at.dt.strftime('%Y-%m'), as_index=False).size().sort_values("listened_at")
df_monthly_dist
# Out:
#    listened_at  size
# 0      2025-01  2186
# 1      2025-03  1910
# 2      2025-04  2057
# 3      2025-05  2567
# 4      2025-06  1594
# 5      2025-07  1067
# 6      2025-08  1334
# 7      2025-09  1118
# 8      2025-10  1094
# 9      2025-11  1129
# 10     2025-12   662

# %%
fig_monthly_dist = px.bar(df_monthly_dist, x="listened_at", y="size")
fig_monthly_dist.show()

# %%
df_2025.sort_values("listened_at")
# Out:
#             artist_name                             track_name  \
# 74703  Brutalismus 3000                           Europaträume
# 74702         Mutilator                      Can You Feel It?!
# 74701    Snow Strippers                      We Both Suffocate
# 74700       underscores       Stupid (Can’t run from the urge)
# 74699             Smino  Hoe-nouns (feat. Thundercat & reggie)
# ...                 ...                                    ...
# 26951      Lover's Skit          No Te Metas - Sassy 009 Remix
# 26950      Skin On Skin                        Let Me Say This
# 26949  The Crying Nudes                                joyride
# 26948          EsDeeKid                                 4 Raws
# 26947            Oli XL                        CONSPIRACY GIRL
#
#                     listened_at
# 74703 2025-01-01 01:07:47+00:00
# 74702 2025-01-01 01:10:27+00:00
# 74701 2025-01-01 01:15:13+00:00
# 74700 2025-01-01 01:17:56+00:00
# 74699 2025-01-01 17:58:08+00:00
# ...                         ...
# 26951 2025-12-17 09:52:29+00:00
# 26950 2025-12-17 09:55:27+00:00
# 26949 2025-12-17 09:59:40+00:00
# 26948 2025-12-17 10:01:17+00:00
# 26947 2025-12-17 10:03:44+00:00
#
# [16718 rows x 3 columns]

# %%
df_history.groupby(df_history.listened_at.dt.strftime('%Y-%m'), as_index=False).size().sort_values("listened_at")
# Out:
#    listened_at  size
# 0      2021-05   715
# 1      2021-06  1210
# 2      2021-07  1307
# 3      2021-08  1167
# 4      2021-09  2137
# 5      2021-10  2428
# 6      2021-11  2536
# 7      2021-12  1987
# 8      2022-01  1974
# 9      2022-02  2075
# 10     2022-03  1502
# 11     2022-04  2009
# 12     2022-05  2535
# 13     2022-06  1548
# 14     2022-07  2010
# 15     2022-08  2195
# 16     2022-09  2171
# 17     2022-10  2174
# 18     2022-11  1792
# 19     2022-12  1613
# 20     2023-01  1510
# 21     2023-02  2279
# 22     2023-03  2401
# 23     2023-04  2086
# 24     2023-05  2494
# 25     2023-06  1521
# 26     2023-07  1091
# 27     2023-08  1312
# 28     2023-09  1798
# 29     2023-10  2371
# 30     2023-11  2681
# 31     2023-12  2364
# 32     2024-01  2335
# 33     2024-02  2041
# 34     2024-03  1812
# 35     2024-04  1746
# 36     2024-05  1935
# 37     2024-06  1669
# 38     2024-07  2052
# 39     2024-08  1289
# 40     2024-09  2292
# 41     2024-10  2844
# 42     2024-11  2878
# 43     2024-12  2235
# 44     2025-01  2186
# 45     2025-03  1910
# 46     2025-04  2057
# 47     2025-05  2567
# 48     2025-06  1594
# 49     2025-07  1067
# 50     2025-08  1334
# 51     2025-09  1118
# 52     2025-10  1094
# 53     2025-11  1129
# 54     2025-12   662

# %% [markdown]
# ### Getting the missing data in the period 2025-01-30 to 2025-03-09

# %%
import json

with open("../data/spotify/official_export/Streaming_History_Audio_2024_21.json") as in_file_1:
    missing_pt_1 = json.load(in_file_1)
with open("../data/spotify/official_export/Streaming_History_Audio_2024-2025_22.json") as in_file_2:
    missing_pt_2 = json.load(in_file_2)
with open("../data/spotify/official_export/Streaming_History_Audio_2025_23.json") as in_file_3:
    missing_pt_3 = json.load(in_file_3)

# %%
df_missing = pd.DataFrame.from_records(missing_pt_1+missing_pt_2+missing_pt_3)

# filtering only relevant columns
df_missing = df_missing[['ts', 'ms_played', 'master_metadata_track_name', 'master_metadata_album_artist_name', 'spotify_track_uri']]

# convert to datetime
df_missing["ts"] = pd.to_datetime(df_missing["ts"], format="%Y-%m-%dT%H:%M:%SZ", utc=True)

# removing podcast entries
df_missing = df_missing[df_missing.spotify_track_uri.notna()]

# filter the relevant area of data
df_missing = df_missing[df_missing.ts >= datetime(2025, 1, 30, tzinfo=timezone.utc)]
df_missing = df_missing[df_missing.ts <= datetime(2025, 3, 10, tzinfo=timezone.utc)]

df_missing["track_id"] = df_missing.spotify_track_uri.apply(lambda x: x.split(":")[-1])
df_missing
# Out:
#                              ts  ms_played  \
# 28242 2025-01-30 05:49:30+00:00     185701
# 28243 2025-01-30 05:50:57+00:00      84279
# 28244 2025-01-30 05:52:16+00:00      49250
# 28245 2025-01-30 05:54:34+00:00     139361
# 28246 2025-01-30 05:58:51+00:00     256586
# ...                         ...        ...
# 35077 2025-03-09 19:34:11+00:00       6861
# 35078 2025-03-09 19:34:17+00:00       5700
# 35079 2025-03-09 19:34:30+00:00      13165
# 35080 2025-03-09 19:34:39+00:00       8277
# 35081 2025-03-09 19:34:49+00:00       9578
#
#                               master_metadata_track_name  \
# 28242                                            Gate 13
# 28243                              Dont Believe the Hype
# 28244                                          Paro Hour
# 28245                                         SPIJKERBOM
# 28246                                      Herz Am Rasen
# ...                                                  ...
# 35077                              133 (Ode to Freshman)
# 35078                                        Chess Bling
# 35079                                            Rosetta
# 35080                                             Breeze
# 35081  Astronaut (Something About Your Love) - Marius...
#
#       master_metadata_album_artist_name                     spotify_track_uri  \
# 28242                       Karashnikov  spotify:track:7mXxHnBa1MtQrS1oxFZYy3
# 28243                          Buchecha  spotify:track:0vNqsKGdZ5zi0tDZ2FHkbA
# 28244                            Luciid  spotify:track:2nMMR3I4OkCx2bXSEenuHB
# 28245                       Vieze Asbak  spotify:track:3vK4A2BPFWDe4FatXwQhdN
# 28246                 Johannes Schuster  spotify:track:3Xex3pAdv3t2fFtc1rimRE
# ...                                 ...                                   ...
# 35077                      Chuck Sutton  spotify:track:0Gfg7xE8RfmCXdtCAGVVUD
# 35078                      Chuck Sutton  spotify:track:1UnTjDAmlJafzCKR33m35q
# 35079                      Chuck Sutton  spotify:track:0UyMWzjPTnEaEEIkDtKKBW
# 35080                            Marius  spotify:track:4Exwb3OMn3WLkAPMwb0BCa
# 35081                        Mansionair  spotify:track:0iMW5zLducv3oRDExU9pUt
#
#                      track_id
# 28242  7mXxHnBa1MtQrS1oxFZYy3
# 28243  0vNqsKGdZ5zi0tDZ2FHkbA
# 28244  2nMMR3I4OkCx2bXSEenuHB
# 28245  3vK4A2BPFWDe4FatXwQhdN
# 28246  3Xex3pAdv3t2fFtc1rimRE
# ...                       ...
# 35077  0Gfg7xE8RfmCXdtCAGVVUD
# 35078  1UnTjDAmlJafzCKR33m35q
# 35079  0UyMWzjPTnEaEEIkDtKKBW
# 35080  4Exwb3OMn3WLkAPMwb0BCa
# 35081  0iMW5zLducv3oRDExU9pUt
#
# [6816 rows x 6 columns]

# %%
# unique_track_ids = [ id.split(":")[-1] for id in df_missing.spotify_track_uri.dropna().unique().tolist() ]
# print(len(unique_track_ids))

# # Get duration of each track to determine if a "scrobble", per last.fm, has happened.
# import json
# import spotipy
# from spotipy.oauth2 import SpotifyOAuth

# with open("../secrets/data-retriever.json") as f:
#     client_json = json.load(f)

# sp = spotipy.Spotify(
#     auth_manager=SpotifyOAuth(
#         client_id=client_json["client_id"],
#         client_secret=client_json["client_secret"],
#         redirect_uri="http://127.0.0.1:8000/callback",
#         ))

# song_duration = []
# for idx in range(0, len(unique_track_ids), 50):
#     track_ids = unique_track_ids[idx:idx+50]

#     results = sp.tracks(track_ids)
#     for track in results["tracks"]:
#         song = {}
#         song["track_id"] = track["id"]
#         song["duration_ms"] = track["duration_ms"]
#         song_duration.append(song)

# %% [markdown]
# By retrieving the length of each track, we can apply conditions to narrow down if a track was "scrobbled" according to "last.fm":
# - The track must be longer than 30 seconds.
# - And the track has been played for at least half its duration, or for 4 minutes (whichever occurs earlier.)

# %%
# df_song_duration = pd.DataFrame.from_records(song_duration)
# res_df = pd.merge(df_missing, df_song_duration, on="track_id")
# res_df = res_df[res_df.ms_played >= res_df.duration_ms/2]
# res_df = res_df[res_df.duration_ms > 30000]
# res_df.to_csv("../data/spotify/missing_data_feb_mar_2025.csv")

# %%
res_df = pd.read_csv("../data/spotify/missing_data_feb_mar_2025.csv")
res_df = res_df[['ts', 'master_metadata_track_name', 'master_metadata_album_artist_name']]
res_df = res_df.rename(
    {
        "ts": "listened_at", 
        "master_metadata_track_name": "track_name",
        "master_metadata_album_artist_name": "artist_name"
    }, axis=1
)
res_df["listened_at"] = pd.to_datetime(res_df.listened_at, utc=True)
res_df
# Out:
#                    listened_at                       track_name  \
# 0    2025-01-30 05:49:30+00:00                          Gate 13
# 1    2025-01-30 05:54:34+00:00                       SPIJKERBOM
# 2    2025-01-30 05:58:51+00:00                    Herz Am Rasen
# 3    2025-01-30 06:43:48+00:00             Johnny johnny johnny
# 4    2025-01-30 06:47:12+00:00                       Loansharks
# ...                        ...                              ...
# 2764 2025-03-09 19:15:27+00:00    Dancing with your eyes closed
# 2765 2025-03-09 19:17:21+00:00  source experience analyzed love
# 2766 2025-03-09 19:20:05+00:00                         With you
# 2767 2025-03-09 19:24:08+00:00                           Garden
# 2768 2025-03-09 19:27:29+00:00                     Forever Yung
#
#             artist_name
# 0           Karashnikov
# 1           Vieze Asbak
# 2     Johannes Schuster
# 3           underscores
# 4           underscores
# ...                 ...
# 2764       Jane Remover
# 2765      meat computer
# 2766         Bassvictim
# 2767   Maria Somerville
# 2768          Yung Lean
#
# [2769 rows x 3 columns]

# %% [markdown]
# Next steps:
# - Integrate the missing data into the result table
# - Remove the data from the missing area
# - Ensure that the artists from the "missing" dataset matches with the rest of the main table
# - Insert into PostgreSQL?

# %%
start = datetime(2025, 1, 30, tzinfo=timezone.utc)
end = datetime(2025, 3, 10, tzinfo=timezone.utc)
mask = (df_2025.listened_at<start) & (df_2025.listened_at<end)
df_2025.loc[~mask]
# Out:
#                   artist_name                                    track_name  \
# 26947                  Oli XL                               CONSPIRACY GIRL
# 26948                EsDeeKid                                        4 Raws
# 26949        The Crying Nudes                                       joyride
# 26950            Skin On Skin                               Let Me Say This
# 26951            Lover's Skit                 No Te Metas - Sassy 009 Remix
# ...                       ...                                           ...
# 43660             underscores                          Johnny johnny johnny
# 43661  STINGER BROTHERS X U H  НЕ СМЕЙСЯ МНЕ В СПИНУ - HERMANN GEWALT Remix
# 43662       Johannes Schuster                                 Herz Am Rasen
# 43663             Vieze Asbak                                    SPIJKERBOM
# 43664             Karashnikov                                       Gate 13
#
#                     listened_at
# 26947 2025-12-17 10:03:44+00:00
# 26948 2025-12-17 10:01:17+00:00
# 26949 2025-12-17 09:59:40+00:00
# 26950 2025-12-17 09:55:27+00:00
# 26951 2025-12-17 09:52:29+00:00
# ...                         ...
# 43660 2025-01-30 06:39:44+00:00
# 43661 2025-01-30 06:38:17+00:00
# 43662 2025-01-30 05:54:34+00:00
# 43663 2025-01-30 05:52:16+00:00
# 43664 2025-01-30 05:46:25+00:00
#
# [14546 rows x 3 columns]

# %%
df_2025_full = pd.concat([res_df, df_2025]).sort_values("listened_at").reset_index()
df_2025_full.shape
# Out:
# (19487, 4)

# %%
df_dist = df_2025_full.groupby(df_2025_full.listened_at.dt.strftime('%Y-%m'), as_index=False).size().sort_values("listened_at")
fig_dist = px.bar(df_dist, x="listened_at", y="size")
fig_dist.show()

# %%
df_2025_full.groupby(df_2025_full.listened_at.dt.strftime('%Y-%m'), as_index=False).size().sort_values("listened_at")
# Out:
#    listened_at  size
# 0      2025-01  2427
# 1      2025-02  1891
# 2      2025-03  2547
# 3      2025-04  2057
# 4      2025-05  2567
# 5      2025-06  1594
# 6      2025-07  1067
# 7      2025-08  1334
# 8      2025-09  1118
# 9      2025-10  1094
# 10     2025-11  1129
# 11     2025-12   662

# %% [markdown]
# need data setup function
