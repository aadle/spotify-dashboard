# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import json

# %%
with open("secrets/data-retriever.json") as f:
    client_json = json.load(f)

# %%
sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id=client_json["client_id"],
        client_secret=client_json["client_secret"],
        redirect_uri="http://127.0.0.1:8000/callback",
        # scope="user-read-recently-played"
        scope="user-library-read"
        )
    )

# %%
q = sp.current_user_saved_tracks(limit=20, market="NO")

# %%
q
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=0&limit=20&market=NO',
#  'items': [{'added_at': '2025-11-29T20:11:15Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3L3ejltt5dmjXkES4YSGKX'},
#        'href': 'https://api.spotify.com/v1/artists/3L3ejltt5dmjXkES4YSGKX',
#        'id': '3L3ejltt5dmjXkES4YSGKX',
#        'name': 'Oli XL',
#        'type': 'artist',
#        'uri': 'spotify:artist:3L3ejltt5dmjXkES4YSGKX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6MLL5vClk79Yhned782Crg'},
#      'href': 'https://api.spotify.com/v1/albums/6MLL5vClk79Yhned782Crg',
#      'id': '6MLL5vClk79Yhned782Crg',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d474bad706c7d68313c66615'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d474bad706c7d68313c66615'},
# ...

# %% [markdown]
# ## archive

# %%
recently_played = sp.current_user_recently_played(limit=50)

# %%
type(sp)
# Out:
# spotipy.client.Spotify

# %% [markdown]
# Vil tracke `track`, `played_at`, `duration_ms`, `id`, `'artists'[0]['name']`

# %%
print(recently_played["items"][0]["track"]["name"])
print(recently_played["items"][0]["track"]["artists"][0]["name"])
print(recently_played["items"][0]["track"]["id"])
print(recently_played["items"][0]["track"]["duration_ms"])
print(recently_played["items"][0]["played_at"], type(recently_played["items"][0]["played_at"]))
print(recently_played["items"][0]["track"]["album"]["album_type"])
print(recently_played["items"][0]["track"]["album"]["name"])
# Out:
# Delusional Conclusion
# Ragnhild og
# 5bvcPN2SGbKXC2oet5f5Ni
# 252386
# 2025-11-28T12:20:12.897Z <class 'str'>
# album
# Might as Well Just Cause a Scene

# %%
for item in recently_played['items']:
    track = item['track']
    played_at = item['played_at']
    print(f"{track['name']} by {track['artists'][0]['name']} - Played at: {played_at}")
# Out:
# Delusional Conclusion by Ragnhild og - Played at: 2025-11-28T12:20:12.897Z
# developed photos by Ragnhild og - Played at: 2025-11-28T12:12:53.641Z
# Habits by Ragnhild og - Played at: 2025-11-28T12:11:49.066Z
# Clairo by Ragnhild og - Played at: 2025-11-28T12:07:22.484Z
# Avoid by Ragnhild og - Played at: 2025-11-28T12:03:49.108Z
# The Future by Ragnhild og - Played at: 2025-11-28T12:00:01.325Z
# ane fred og ingen fare by Ragnhild og - Played at: 2025-11-28T11:56:14.553Z
# Better Than You by Ragnhild og - Played at: 2025-11-28T11:55:34.322Z
# refleksjoner by Ragnhild og - Played at: 2025-11-28T11:52:18.995Z
# Am I Doomed? by Ragnhild og - Played at: 2025-11-28T11:49:29.027Z
# Limerence by Ragnhild og - Played at: 2025-11-28T11:46:00.464Z
# reading about by Ragnhild og - Played at: 2025-11-28T11:42:14.498Z
# Now That I Don't Cry Anymore by Ragnhild og - Played at: 2025-11-28T11:41:52.414Z
# Once It Is Revealed by Ragnhild og - Played at: 2025-11-28T11:37:27.801Z
# ...

# %% [markdown]
# Trenger en måte å hente ut alle sanger spilt fra gårsdagen.

# %%
from datetime import datetime
yesterday = datetime.strptime(datetime.today().strftime("%Y-%m-%d"), "%Y-%m-%d").timestamp() * 1000 - 3600 * 24 * 1000
print(datetime.fromtimestamp(yesterday/1000.0))
print(datetime.strptime(datetime.today().strftime("%Y-%m-%d"), "%Y-%m-%d"))
# Out:
# 2025-11-27 00:00:00
# 2025-11-28 00:00:00

# %%
from dateutil import parser
# 2025-11-28T11:42:14.498Z
parser.parse(recently_played["items"][0]["played_at"])
# Out:
# datetime.datetime(2025, 11, 28, 12, 20, 12, 897000, tzinfo=tzutc())

# %%
from typing import Dict, List
from datetime import datetime, timedelta
from dateutil import parser
import pytz

def retrieve_data_from_played_track(recently_played:Dict) -> List: # Can be improved upon
    tracks_played = []
    for item in recently_played["items"]:
        track_info = {}         

        # Extract data from nested dictionary
        track = item["track"]
        track_name = track["name"]
        main_artist = track["name"]
        spotify_track_id = track["id"]
        duration_ms = track["duration_ms"]
        played_at = item["played_at"]
        album_name = track["album"]["name"]
        album_type = track["album"]["album_type"]


        # Insert data into a simpler dictionary
        track_info["track_name"] = track_name
        track_info["main_artist"] = main_artist 
        track_info["spotify_track_id"] = spotify_track_id
        track_info["duration_ms"] = duration_ms
        track_info["played_at"] = played_at # Q: convert now or later with dateutil.parser.parse?
        track_info["album"] = album_name
        track_info["album_type"] = album_type

        tracks_played.append(track_info)

    return tracks_played

def retrieve_listening_history(sp:spotipy.client.Spotify) -> Dict:
    today = pytz.utc.localize(datetime.today().replace(hour=0, minute=0, second=0, microsecond=0))
    yesterday = today - timedelta(days=1)

    today_ms = int(today.timestamp() * 1000)
    yesterday_ms = int(yesterday.timestamp() * 1000)

    recently_played = sp.current_user_recently_played(limit=50, after=yesterday_ms) # Starts retrieving from midnight of yesterday
    print(len(recently_played["items"]))

    played_yesterday = []

    for item in recently_played["items"]: 
        played_at_str = item["played_at"]
        played_at = parser.parse(played_at_str.replace("Z", "+00:00"))
        print(played_at, today)
        print(played_at < today)

        # add to list if played yesterday
        if played_at < today:
            print("added!")
            played_yesterday.append(item)
    
    return played_yesterday

# %%
sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id=client_json["client_id"],
        client_secret=client_json["client_secret"],
        redirect_uri="http://127.0.0.1:8000/callback",
        scope="user-read-recently-played"
        # scope="user-library-read"
        )
    )

today = pytz.utc.localize(datetime.today().replace(hour=0, minute=0, second=0, microsecond=0))
yesterday = today - timedelta(days=2)

today_ms = int(today.timestamp() * 1000)
yesterday_ms = int(yesterday.timestamp() * 1000)
print(today, yesterday)
print(today > yesterday)

recently_played_after_yesterday = sp.current_user_recently_played(limit=50, after=yesterday_ms)
# Out:
# 2025-11-28 00:00:00+00:00 2025-11-26 00:00:00+00:00
# True

# %%
recently_played_after_yesterday["items"]
# Out:
# [{'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7f8ydynRRnrJBqWxevKLcM'},
#       'href': 'https://api.spotify.com/v1/artists/7f8ydynRRnrJBqWxevKLcM',
#       'id': '7f8ydynRRnrJBqWxevKLcM',
#       'name': 'Bassvictim',
#       'type': 'artist',
#       'uri': 'spotify:artist:7f8ydynRRnrJBqWxevKLcM'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
# ...

# %%
recently_played["items"]
# Out:
# [{'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7f8ydynRRnrJBqWxevKLcM'},
#       'href': 'https://api.spotify.com/v1/artists/7f8ydynRRnrJBqWxevKLcM',
#       'id': '7f8ydynRRnrJBqWxevKLcM',
#       'name': 'Bassvictim',
#       'type': 'artist',
#       'uri': 'spotify:artist:7f8ydynRRnrJBqWxevKLcM'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
# ...

# %%
import pytz
from datetime import datetime, timedelta


today = pytz.utc.localize(datetime.today().replace(hour=0, minute=0, second=0, microsecond=0))
yesterday = today - timedelta(days=1)

played_yesterday = []
not_played_yesterday = []
done = False 
while not done:
    for item in recently_played["items"][::-1]:
        played_at_str = item["played_at"]
        played_at = parser.parse(played_at_str)

        # add to list if played yesterday
        if yesterday <= played_at < today:
            print("e")
            played_yesterday.append(item)
        elif played_at >= today:
            print("target day hit")
            not_played_yesterday.append(item)
            done = True
            # return played_yesterday

print(len(played_yesterday))
print(played_yesterday)
# Out:
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# target day hit
# 26
# ...

# %%
retrieve_data_from_played_track(recently_played=recently_played)
# Out:
# [{'track_name': 'Delusional Conclusion',
#   'main_artist': 'Delusional Conclusion',
#   'spotify_track_id': '5bvcPN2SGbKXC2oet5f5Ni',
#   'duration_ms': 252386,
#   'played_at': '2025-11-28T12:20:12.897Z',
#   'album': 'Might as Well Just Cause a Scene',
#   'album_type': 'album'},
#  {'track_name': 'developed photos',
#   'main_artist': 'developed photos',
#   'spotify_track_id': '0Kh0CXQVWev0T6XfLu27HT',
#   'duration_ms': 64493,
#   'played_at': '2025-11-28T12:12:53.641Z',
#   'album': 'Might as Well Just Cause a Scene',
#   'album_type': 'album'},
#  {'track_name': 'Habits',
#   'main_artist': 'Habits',
#   'spotify_track_id': '59jZQKaHuOgCyqXL0M7hCi',
#   'duration_ms': 266680,
#   'played_at': '2025-11-28T12:11:49.066Z',
#   'album': 'Might as Well Just Cause a Scene',
#   'album_type': 'album'},
#  {'track_name': 'Clairo',
#   'main_artist': 'Clairo',
#   'spotify_track_id': '05AnW8YkW5LXZjN22nUn9x',
#   'duration_ms': 213653,
#   'played_at': '2025-11-28T12:07:22.484Z',
# ...

# %%
import json
import spotipy
from spotipy.oauth2 import SpotifyOAuth

with open("secrets/data-retriever.json") as f:
    client_json = json.load(f)

sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id=client_json["client_id"],
        client_secret=client_json["client_secret"],
        redirect_uri="http://127.0.0.1:8000/callback",
        scope="user-library-read")
)
results = sp.current_user_saved_tracks()
for idx, item in enumerate(results["items"]):
    track = item["track"]
    print(idx, track["artists"][0]["name"], "-", track["name"])
# Out:
# 0 EsDeeKid - 4 Raws
# 1 Oli XL - CONSPIRACY GIRL
# 2 Slimesito - Ms. Jackson
# 3 Geese - Cobra
# 4 Geese - Husbands
# 5 Evita Manji - Oil/Too Much
# 6 Evita Manji - Body/Prison
# 7 Bassvictim - Welcome
# 8 Ragnhild og - Avoid
# 9 Ragnhild og - Habits
# 10 Dj Billybool - 넘버 원 // NUMMER ETT Part 2 - Effie & Eurohead Remix
# 11 Bassvictim - Air on a G String
# 12 Smerz - Big dreams
# 13 Snowy Band - Love You To Death
# 14 Wet - Bound
# 15 Wet - Close Range
# 16 Sex Week - Bluff
# 17 Phonique - For The Time Being
# 18 Pretty V - Better than Before
# 19 Odeal - Miami (feat. Leon Thomas)

# %%
results = sp.current_user_saved_tracks(offset=int(95*50), limit=50)

# %%
artists = results["items"][0]["track"]["artists"]
[q["name"] for q in artists]
# Out:
# ['Flume']

# %%
results
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=4750&limit=50',
#  'items': [],
#  'limit': 50,
#  'next': None,
#  'offset': 4750,
#  'previous': 'https://api.spotify.com/v1/me/tracks?offset=4700&limit=50',
#  'total': 4732}

# %%
len(results["items"])
# Out:
# 0

# %%
type(results["next"])
# Out:
# NoneType

# %% [markdown]
# ## ReccoBeats

# %%
import requests

url = "https://api.reccobeats.com/v1/audio-features"

payload = {"ids": [ 
    # "6RM6SBmaiv1ouUxh9nmQL", 
    # "8212bab8-5911-48a0-b177-24923ef2329a", 
    # "4KW1lqgSr8TKrvBII0Brf8", 
    # "5LJ4ig9cMvjui3li1mrNRl",
    # "1y9v9gcYrxCy2YkKaXibQ4",
    "2T8yuUKl1nhmtaIocqWo4i",
    ]
    }
headers = {
  'Accept': 'application/json'
}

response = requests.request("GET", url, headers=headers, params=payload)

print(response.text)
# Out:
# {"content":[]}

# %%
# Cutoff for ReccoBeats features is about end of april 2025.

# %%
response.json()
# Out:
# {'content': []}

# %% [markdown]
# ## Spotify playlists

# %%
import json
import spotipy
from spotipy.oauth2 import SpotifyOAuth

with open("secrets/data-retriever.json") as f:
    client_json = json.load(f)

sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id=client_json["client_id"],
        client_secret=client_json["client_secret"],
        redirect_uri="http://127.0.0.1:8000/callback",
        scope="playlist-read-private")
)
results = sp.playlist_items(
    "0ovRUVQQv9ZL0jEhfokytE",
    fields = "next, items(added_at, track(duration_ms, id, name, popularity, album(name, id, release_date), artists.name))",
    offset=20*5
    # fields="items(added_by.id,track(name,href,album(name,href)))"
    )

# %%
results
# Out:
# {'items': [{'track': {'artists': [{'name': 'Iglooghost'}],
#     'album': {'name': 'Tidal Memory Exo',
#      'release_date': '2024-05-10',
#      'id': '7CQp27clxVYy6Ou6jXht6g'},
#     'duration_ms': 201028,
#     'name': 'New Species',
#     'popularity': 35,
#     'id': '43IxujU228QDYxlnMcotzW'},
#    'added_at': '2025-10-26T18:07:10Z'},
#   {'track': {'artists': [{'name': 'Iglooghost'}],
#     'album': {'name': 'Tidal Memory Exo',
#      'release_date': '2024-05-10',
#      'id': '7CQp27clxVYy6Ou6jXht6g'},
#     'duration_ms': 205270,
#     'name': 'flux•Cocoon',
#     'popularity': 30,
#     'id': '2A72oKvGmcmPW4C4SXBZMp'},
#    'added_at': '2025-10-26T18:07:10Z'},
#   {'track': {'artists': [{'name': 'Varg²™'}, {'name': 'Chapo'}],
#     'album': {'name': 'G41 Änglar/Gen5Freestyle',
#      'release_date': '2025-10-24',
#      'id': '1Ta1QNVIqJX8XvBgLTbftQ'},
#     'duration_ms': 167916,
#     'name': 'G41 Änglar/Gen5Freestyle',
#     'popularity': 33,
# ...

# %%
len(results["items"])
# Out:
# 100

# %%
from typing import Dict, List
def helper_extract(data:Dict) -> List: # need better name
    # Extract out:
    # - ["track"]["id"] - Spotify ID for the track

    # - ["track"]["name"] - track name
    # - ["track"]["artists"]["name"] - DETTE ER EN LISTE!!!
        # - artist: [0] er hovedartist
            # if len() > 0
            # - features: [1:] indekser utover er features
            # else:
            # - features = [""]

    # - ["added_at"] - timestamp when track was added
    # - ["track"]["duration_ms"] - duration in ms

    # - ["track"]["album"]["name"] - Album name
    # - ["track"]["album"]["release_date"] - Release date of album
    # - ["track"]["album"]["id"] - Spotify ID for album
    # - 
    # - ["track"]["popularity"] - fluctuating popularity metric 

    items = data["items"]

    records_out = [] 

    for idx, item in enumerate(items):
        track_entry = {}
        track = item["track"]

        track_entry["spotify_id"] = track["id"]

        track_entry["track_name"] = track["name"]
        track_entry["main_artist"] = track["artists"][0]["name"]

        if len(track["artists"]) > 1:
            track_entry["featured_artists"] = [
                feature["name"] for feature in track["artists"][1:]
            ]
        else:
            track_entry["featured_artists"] = None

        track_entry["added_at"] = item["added_at"]
        track_entry["duration_ms"] = track["duration_ms"]

        track_entry["album_name"] = track["album"]["name"]
        track_entry["album_release_date"] = track["album"]["release_date"]
        track_entry["album_id"] = track["album"]["id"]

        records_out.append(track_entry)

    # return dict_out
    return records_out

# %%
helper_extract(results)
# Out:
# [{'spotify_id': '2zf1izCOz2F22PF27uhxRF',
#   'track_name': 'Love Takes Miles',
#   'main_artist': 'Cameron Winter',
#   'featured_artists': None,
#   'added_at': '2025-07-05T19:29:35Z',
#   'duration_ms': 198386,
#   'album_name': 'Heavy Metal',
#   'album_release_date': '2024-12-06',
#   'album_id': '7mOrnQqDad3RgYQsJGaaqk'},
#  {'spotify_id': '2FZsOypXRoYIrGI6s8C3Zm',
#   'track_name': '$0',
#   'main_artist': 'Cameron Winter',
#   'featured_artists': None,
#   'added_at': '2025-07-05T19:29:43Z',
#   'duration_ms': 403853,
#   'album_name': 'Heavy Metal',
#   'album_release_date': '2024-12-06',
#   'album_id': '7mOrnQqDad3RgYQsJGaaqk'},
#  {'spotify_id': '6XXZVVmYESJJKigExJBEPN',
#   'track_name': 'DASH SNOW',
#   'main_artist': 'Dean Blunt',
#   'featured_artists': None,
#   'added_at': '2025-07-05T19:30:05Z',
#   'duration_ms': 120466,
#   'album_name': 'BLACK METAL 2',
#   'album_release_date': '2021-06-11',
#   'album_id': '33xbAWdpX79o2YtXBiBWQv'},
# ...
